# %% [markdown]
# ### a) Build a language model based on n-grams using the Laplace smoothing method for the following models

# %%
from collections import defaultdict
from nltk import word_tokenize

# %%
def unigram_count(tokens):
    tokens_len = len(tokens) # tổng số token
    V = len(set(tokens))     # vocab size
    unigram_counts = dict()
    for token in tokens:
        if token in unigram_counts:
            unigram_counts[token] += 1
        else:
            unigram_counts[token] = 1
    return unigram_counts, V, tokens_len

    
def laplace_smooth_unigram_prob(word, unigram_counts, V, tokens_len):
    return (unigram_counts[word]+1) / (tokens_len + V)


corpus = "the cat jumped over the dog . the dog ran on the floor ."
tokens = word_tokenize(corpus.lower()) # vocabularies
unigram_counts, V, tokens_len = unigram_count(tokens)
for word in tokens:
    print(f"p({word}) = {laplace_smooth_unigram_prob(word, unigram_counts,V, tokens_len):.5f}")
# Out:
# p(the) = 0.21739
# p(cat) = 0.08696
# p(jumped) = 0.08696
# p(over) = 0.08696
# p(the) = 0.21739
# p(dog) = 0.13043
# p(.) = 0.13043
# p(the) = 0.21739
# p(dog) = 0.13043
# p(ran) = 0.08696
# p(on) = 0.08696
# p(the) = 0.21739
# p(floor) = 0.08696
# p(.) = 0.13043

# %%
def bigram_count(tokens):
    tokens_len = len(tokens) 
    V=len(set(tokens)) 
    bigram_counts = defaultdict(int)
    unigram_counts = defaultdict(int)

    for i in range(tokens_len - 1):
        bigram = (tokens[i], tokens[i+1])
        bigram_counts[bigram] += 1
        unigram_counts[tokens[i]] += 1
    unigram_counts[tokens[-1]] += 1
    
    return bigram_counts, unigram_counts, V, tokens_len

def laplace_smooth_bigram_prob(w1, w2, bigram_counts, unigram_counts, V):
    return (bigram_counts[(w1, w2)] + 1) / (unigram_counts[w1] + V)

# Example usage
corpus = "the cat jumped over the dog . the dog ran on the floor ."
tokens = word_tokenize(corpus.lower())
bigram_counts, unigram_counts, V, tokens_len = bigram_count(tokens)

print("Laplace-smoothed bigram probabilities: ")
for w1 in tokens:
    for w2 in tokens:
        print(f"P({w2}|{w1}) = {laplace_smooth_bigram_prob(w1, w2, bigram_counts, unigram_counts, V):.5f}")
# Out:
# Laplace-smoothed bigram probabilities:
# P(the|the) = 0.07692
# P(cat|the) = 0.15385
# P(jumped|the) = 0.07692
# P(over|the) = 0.07692
# P(the|the) = 0.07692
# P(dog|the) = 0.23077
# P(.|the) = 0.07692
# P(the|the) = 0.07692
# P(dog|the) = 0.23077
# P(ran|the) = 0.07692
# P(on|the) = 0.07692
# P(the|the) = 0.07692
# P(floor|the) = 0.15385
# P(.|the) = 0.07692
# P(the|cat) = 0.10000
# P(cat|cat) = 0.10000
# P(jumped|cat) = 0.20000
# P(over|cat) = 0.10000
# P(the|cat) = 0.10000
# P(dog|cat) = 0.10000
# P(.|cat) = 0.10000
# P(the|cat) = 0.10000
# P(dog|cat) = 0.10000
# P(ran|cat) = 0.10000
# P(on|cat) = 0.10000
# P(the|cat) = 0.10000
# P(floor|cat) = 0.10000
# P(.|cat) = 0.10000
# P(the|jumped) = 0.10000
# P(cat|jumped) = 0.10000
# P(jumped|jumped) = 0.10000
# P(over|jumped) = 0.20000
# P(the|jumped) = 0.10000
# P(dog|jumped) = 0.10000
# P(.|jumped) = 0.10000
# P(the|jumped) = 0.10000
# P(dog|jumped) = 0.10000
# P(ran|jumped) = 0.10000
# P(on|jumped) = 0.10000
# P(the|jumped) = 0.10000
# P(floor|jumped) = 0.10000
# P(.|jumped) = 0.10000
# P(the|over) = 0.20000
# P(cat|over) = 0.10000
# P(jumped|over) = 0.10000
# P(over|over) = 0.10000
# P(the|over) = 0.20000
# P(dog|over) = 0.10000
# P(.|over) = 0.10000
# P(the|over) = 0.20000
# P(dog|over) = 0.10000
# P(ran|over) = 0.10000
# P(on|over) = 0.10000
# P(the|over) = 0.20000
# P(floor|over) = 0.10000
# P(.|over) = 0.10000
# P(the|the) = 0.07692
# P(cat|the) = 0.15385
# P(jumped|the) = 0.07692
# P(over|the) = 0.07692
# P(the|the) = 0.07692
# P(dog|the) = 0.23077
# P(.|the) = 0.07692
# P(the|the) = 0.07692
# P(dog|the) = 0.23077
# P(ran|the) = 0.07692
# P(on|the) = 0.07692
# P(the|the) = 0.07692
# P(floor|the) = 0.15385
# P(.|the) = 0.07692
# P(the|dog) = 0.09091
# P(cat|dog) = 0.09091
# P(jumped|dog) = 0.09091
# P(over|dog) = 0.09091
# P(the|dog) = 0.09091
# P(dog|dog) = 0.09091
# P(.|dog) = 0.18182
# P(the|dog) = 0.09091
# P(dog|dog) = 0.09091
# P(ran|dog) = 0.18182
# P(on|dog) = 0.09091
# P(the|dog) = 0.09091
# P(floor|dog) = 0.09091
# P(.|dog) = 0.18182
# P(the|.) = 0.18182
# P(cat|.) = 0.09091
# P(jumped|.) = 0.09091
# P(over|.) = 0.09091
# P(the|.) = 0.18182
# P(dog|.) = 0.09091
# P(.|.) = 0.09091
# P(the|.) = 0.18182
# P(dog|.) = 0.09091
# P(ran|.) = 0.09091
# P(on|.) = 0.09091
# P(the|.) = 0.18182
# P(floor|.) = 0.09091
# P(.|.) = 0.09091
# P(the|the) = 0.07692
# P(cat|the) = 0.15385
# P(jumped|the) = 0.07692
# P(over|the) = 0.07692
# P(the|the) = 0.07692
# P(dog|the) = 0.23077
# P(.|the) = 0.07692
# P(the|the) = 0.07692
# P(dog|the) = 0.23077
# P(ran|the) = 0.07692
# P(on|the) = 0.07692
# P(the|the) = 0.07692
# P(floor|the) = 0.15385
# P(.|the) = 0.07692
# P(the|dog) = 0.09091
# P(cat|dog) = 0.09091
# P(jumped|dog) = 0.09091
# P(over|dog) = 0.09091
# P(the|dog) = 0.09091
# P(dog|dog) = 0.09091
# P(.|dog) = 0.18182
# P(the|dog) = 0.09091
# P(dog|dog) = 0.09091
# P(ran|dog) = 0.18182
# P(on|dog) = 0.09091
# P(the|dog) = 0.09091
# P(floor|dog) = 0.09091
# P(.|dog) = 0.18182
# P(the|ran) = 0.10000
# P(cat|ran) = 0.10000
# P(jumped|ran) = 0.10000
# P(over|ran) = 0.10000
# P(the|ran) = 0.10000
# P(dog|ran) = 0.10000
# P(.|ran) = 0.10000
# P(the|ran) = 0.10000
# P(dog|ran) = 0.10000
# P(ran|ran) = 0.10000
# P(on|ran) = 0.20000
# P(the|ran) = 0.10000
# P(floor|ran) = 0.10000
# P(.|ran) = 0.10000
# P(the|on) = 0.20000
# P(cat|on) = 0.10000
# P(jumped|on) = 0.10000
# P(over|on) = 0.10000
# P(the|on) = 0.20000
# P(dog|on) = 0.10000
# P(.|on) = 0.10000
# P(the|on) = 0.20000
# P(dog|on) = 0.10000
# P(ran|on) = 0.10000
# P(on|on) = 0.10000
# P(the|on) = 0.20000
# P(floor|on) = 0.10000
# P(.|on) = 0.10000
# P(the|the) = 0.07692
# P(cat|the) = 0.15385
# P(jumped|the) = 0.07692
# P(over|the) = 0.07692
# P(the|the) = 0.07692
# P(dog|the) = 0.23077
# P(.|the) = 0.07692
# P(the|the) = 0.07692
# P(dog|the) = 0.23077
# P(ran|the) = 0.07692
# P(on|the) = 0.07692
# P(the|the) = 0.07692
# P(floor|the) = 0.15385
# P(.|the) = 0.07692
# P(the|floor) = 0.10000
# P(cat|floor) = 0.10000
# P(jumped|floor) = 0.10000
# P(over|floor) = 0.10000
# P(the|floor) = 0.10000
# P(dog|floor) = 0.10000
# P(.|floor) = 0.20000
# P(the|floor) = 0.10000
# P(dog|floor) = 0.10000
# P(ran|floor) = 0.10000
# P(on|floor) = 0.10000
# P(the|floor) = 0.10000
# P(floor|floor) = 0.10000
# P(.|floor) = 0.20000
# P(the|.) = 0.18182
# P(cat|.) = 0.09091
# P(jumped|.) = 0.09091
# P(over|.) = 0.09091
# P(the|.) = 0.18182
# P(dog|.) = 0.09091
# P(.|.) = 0.09091
# P(the|.) = 0.18182
# P(dog|.) = 0.09091
# P(ran|.) = 0.09091
# P(on|.) = 0.09091
# P(the|.) = 0.18182
# P(floor|.) = 0.09091
# P(.|.) = 0.09091

# %%
def trigram_count(tokens):
    tokens_len = len(tokens) # number of tokens
    V=len(set(tokens)) # vocabulary size
    trigram_counts = defaultdict(int)
    bigram_counts = defaultdict(int)
    
    tokens_set = set(tokens)

    for i in range(tokens_len - 2):
        trigram = (tokens[i], tokens[i+1], tokens[i+2])
        trigram_counts[trigram] += 1
        bigram = (tokens[i], tokens[i+1])
        bigram_counts[bigram] += 1
    bigram = (tokens[-2], tokens[-1])
    bigram_counts[bigram] += 1
    
    return trigram_counts, bigram_counts, V

def laplace_smooth_trigram_prob(w1, w2, w3, trigram_counts, bigram_counts, V):
    return (trigram_counts[(w1, w2, w3)] + 1) / (bigram_counts[(w1, w2)] + V)

corpus = "the cat jumped over the dog . the dog ran on the floor ."
tokens = word_tokenize(corpus.lower())
trigram_counts, bigram_counts, V = trigram_count(tokens)

print("Some Laplace-smoothed trigram probabilities:")
for w1 in tokens:
    for w2 in tokens:
        for w3 in tokens:
            print(f"P({w3}|{w1} {w2}) = {laplace_smooth_trigram_prob(w1, w2, w3, trigram_counts, bigram_counts, V):.5f}")
# Out:
# Some Laplace-smoothed trigram probabilities:
# P(the|the the) = 0.11111
# P(cat|the the) = 0.11111
# P(jumped|the the) = 0.11111
# P(over|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(ran|the the) = 0.11111
# P(on|the the) = 0.11111
# P(the|the the) = 0.11111
# P(floor|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the cat) = 0.10000
# P(cat|the cat) = 0.10000
# P(jumped|the cat) = 0.20000
# P(over|the cat) = 0.10000
# P(the|the cat) = 0.10000
# P(dog|the cat) = 0.10000
# P(.|the cat) = 0.10000
# P(the|the cat) = 0.10000
# P(dog|the cat) = 0.10000
# P(ran|the cat) = 0.10000
# P(on|the cat) = 0.10000
# P(the|the cat) = 0.10000
# P(floor|the cat) = 0.10000
# P(.|the cat) = 0.10000
# P(the|the jumped) = 0.11111
# P(cat|the jumped) = 0.11111
# P(jumped|the jumped) = 0.11111
# P(over|the jumped) = 0.11111
# P(the|the jumped) = 0.11111
# P(dog|the jumped) = 0.11111
# P(.|the jumped) = 0.11111
# P(the|the jumped) = 0.11111
# P(dog|the jumped) = 0.11111
# P(ran|the jumped) = 0.11111
# P(on|the jumped) = 0.11111
# P(the|the jumped) = 0.11111
# P(floor|the jumped) = 0.11111
# P(.|the jumped) = 0.11111
# P(the|the over) = 0.11111
# P(cat|the over) = 0.11111
# P(jumped|the over) = 0.11111
# P(over|the over) = 0.11111
# P(the|the over) = 0.11111
# P(dog|the over) = 0.11111
# P(.|the over) = 0.11111
# P(the|the over) = 0.11111
# P(dog|the over) = 0.11111
# P(ran|the over) = 0.11111
# P(on|the over) = 0.11111
# P(the|the over) = 0.11111
# P(floor|the over) = 0.11111
# P(.|the over) = 0.11111
# P(the|the the) = 0.11111
# P(cat|the the) = 0.11111
# P(jumped|the the) = 0.11111
# P(over|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(ran|the the) = 0.11111
# P(on|the the) = 0.11111
# P(the|the the) = 0.11111
# P(floor|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the dog) = 0.09091
# P(cat|the dog) = 0.09091
# P(jumped|the dog) = 0.09091
# P(over|the dog) = 0.09091
# P(the|the dog) = 0.09091
# P(dog|the dog) = 0.09091
# P(.|the dog) = 0.18182
# P(the|the dog) = 0.09091
# P(dog|the dog) = 0.09091
# P(ran|the dog) = 0.18182
# P(on|the dog) = 0.09091
# P(the|the dog) = 0.09091
# P(floor|the dog) = 0.09091
# P(.|the dog) = 0.18182
# P(the|the .) = 0.11111
# P(cat|the .) = 0.11111
# P(jumped|the .) = 0.11111
# P(over|the .) = 0.11111
# P(the|the .) = 0.11111
# P(dog|the .) = 0.11111
# P(.|the .) = 0.11111
# P(the|the .) = 0.11111
# P(dog|the .) = 0.11111
# P(ran|the .) = 0.11111
# P(on|the .) = 0.11111
# P(the|the .) = 0.11111
# P(floor|the .) = 0.11111
# P(.|the .) = 0.11111
# P(the|the the) = 0.11111
# P(cat|the the) = 0.11111
# P(jumped|the the) = 0.11111
# P(over|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(ran|the the) = 0.11111
# P(on|the the) = 0.11111
# P(the|the the) = 0.11111
# P(floor|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the dog) = 0.09091
# P(cat|the dog) = 0.09091
# P(jumped|the dog) = 0.09091
# P(over|the dog) = 0.09091
# P(the|the dog) = 0.09091
# P(dog|the dog) = 0.09091
# P(.|the dog) = 0.18182
# P(the|the dog) = 0.09091
# P(dog|the dog) = 0.09091
# P(ran|the dog) = 0.18182
# P(on|the dog) = 0.09091
# P(the|the dog) = 0.09091
# P(floor|the dog) = 0.09091
# P(.|the dog) = 0.18182
# P(the|the ran) = 0.11111
# P(cat|the ran) = 0.11111
# P(jumped|the ran) = 0.11111
# P(over|the ran) = 0.11111
# P(the|the ran) = 0.11111
# P(dog|the ran) = 0.11111
# P(.|the ran) = 0.11111
# P(the|the ran) = 0.11111
# P(dog|the ran) = 0.11111
# P(ran|the ran) = 0.11111
# P(on|the ran) = 0.11111
# P(the|the ran) = 0.11111
# P(floor|the ran) = 0.11111
# P(.|the ran) = 0.11111
# P(the|the on) = 0.11111
# P(cat|the on) = 0.11111
# P(jumped|the on) = 0.11111
# P(over|the on) = 0.11111
# P(the|the on) = 0.11111
# P(dog|the on) = 0.11111
# P(.|the on) = 0.11111
# P(the|the on) = 0.11111
# P(dog|the on) = 0.11111
# P(ran|the on) = 0.11111
# P(on|the on) = 0.11111
# P(the|the on) = 0.11111
# P(floor|the on) = 0.11111
# P(.|the on) = 0.11111
# P(the|the the) = 0.11111
# P(cat|the the) = 0.11111
# P(jumped|the the) = 0.11111
# P(over|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(ran|the the) = 0.11111
# P(on|the the) = 0.11111
# P(the|the the) = 0.11111
# P(floor|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the floor) = 0.10000
# P(cat|the floor) = 0.10000
# P(jumped|the floor) = 0.10000
# P(over|the floor) = 0.10000
# P(the|the floor) = 0.10000
# P(dog|the floor) = 0.10000
# P(.|the floor) = 0.20000
# P(the|the floor) = 0.10000
# P(dog|the floor) = 0.10000
# P(ran|the floor) = 0.10000
# P(on|the floor) = 0.10000
# P(the|the floor) = 0.10000
# P(floor|the floor) = 0.10000
# P(.|the floor) = 0.20000
# P(the|the .) = 0.11111
# P(cat|the .) = 0.11111
# P(jumped|the .) = 0.11111
# P(over|the .) = 0.11111
# P(the|the .) = 0.11111
# P(dog|the .) = 0.11111
# P(.|the .) = 0.11111
# P(the|the .) = 0.11111
# P(dog|the .) = 0.11111
# P(ran|the .) = 0.11111
# P(on|the .) = 0.11111
# P(the|the .) = 0.11111
# P(floor|the .) = 0.11111
# P(.|the .) = 0.11111
# P(the|cat the) = 0.11111
# P(cat|cat the) = 0.11111
# P(jumped|cat the) = 0.11111
# P(over|cat the) = 0.11111
# P(the|cat the) = 0.11111
# P(dog|cat the) = 0.11111
# P(.|cat the) = 0.11111
# P(the|cat the) = 0.11111
# P(dog|cat the) = 0.11111
# P(ran|cat the) = 0.11111
# P(on|cat the) = 0.11111
# P(the|cat the) = 0.11111
# P(floor|cat the) = 0.11111
# P(.|cat the) = 0.11111
# P(the|cat cat) = 0.11111
# P(cat|cat cat) = 0.11111
# P(jumped|cat cat) = 0.11111
# P(over|cat cat) = 0.11111
# P(the|cat cat) = 0.11111
# P(dog|cat cat) = 0.11111
# P(.|cat cat) = 0.11111
# P(the|cat cat) = 0.11111
# P(dog|cat cat) = 0.11111
# P(ran|cat cat) = 0.11111
# P(on|cat cat) = 0.11111
# P(the|cat cat) = 0.11111
# P(floor|cat cat) = 0.11111
# P(.|cat cat) = 0.11111
# P(the|cat jumped) = 0.10000
# P(cat|cat jumped) = 0.10000
# P(jumped|cat jumped) = 0.10000
# P(over|cat jumped) = 0.20000
# P(the|cat jumped) = 0.10000
# P(dog|cat jumped) = 0.10000
# P(.|cat jumped) = 0.10000
# P(the|cat jumped) = 0.10000
# P(dog|cat jumped) = 0.10000
# P(ran|cat jumped) = 0.10000
# P(on|cat jumped) = 0.10000
# P(the|cat jumped) = 0.10000
# P(floor|cat jumped) = 0.10000
# P(.|cat jumped) = 0.10000
# P(the|cat over) = 0.11111
# P(cat|cat over) = 0.11111
# P(jumped|cat over) = 0.11111
# P(over|cat over) = 0.11111
# P(the|cat over) = 0.11111
# P(dog|cat over) = 0.11111
# P(.|cat over) = 0.11111
# P(the|cat over) = 0.11111
# P(dog|cat over) = 0.11111
# P(ran|cat over) = 0.11111
# P(on|cat over) = 0.11111
# P(the|cat over) = 0.11111
# P(floor|cat over) = 0.11111
# P(.|cat over) = 0.11111
# P(the|cat the) = 0.11111
# P(cat|cat the) = 0.11111
# P(jumped|cat the) = 0.11111
# P(over|cat the) = 0.11111
# P(the|cat the) = 0.11111
# P(dog|cat the) = 0.11111
# P(.|cat the) = 0.11111
# P(the|cat the) = 0.11111
# P(dog|cat the) = 0.11111
# P(ran|cat the) = 0.11111
# P(on|cat the) = 0.11111
# P(the|cat the) = 0.11111
# P(floor|cat the) = 0.11111
# P(.|cat the) = 0.11111
# P(the|cat dog) = 0.11111
# P(cat|cat dog) = 0.11111
# P(jumped|cat dog) = 0.11111
# P(over|cat dog) = 0.11111
# P(the|cat dog) = 0.11111
# P(dog|cat dog) = 0.11111
# P(.|cat dog) = 0.11111
# P(the|cat dog) = 0.11111
# P(dog|cat dog) = 0.11111
# P(ran|cat dog) = 0.11111
# P(on|cat dog) = 0.11111
# P(the|cat dog) = 0.11111
# P(floor|cat dog) = 0.11111
# P(.|cat dog) = 0.11111
# P(the|cat .) = 0.11111
# P(cat|cat .) = 0.11111
# P(jumped|cat .) = 0.11111
# P(over|cat .) = 0.11111
# P(the|cat .) = 0.11111
# P(dog|cat .) = 0.11111
# P(.|cat .) = 0.11111
# P(the|cat .) = 0.11111
# P(dog|cat .) = 0.11111
# P(ran|cat .) = 0.11111
# P(on|cat .) = 0.11111
# P(the|cat .) = 0.11111
# P(floor|cat .) = 0.11111
# P(.|cat .) = 0.11111
# P(the|cat the) = 0.11111
# P(cat|cat the) = 0.11111
# P(jumped|cat the) = 0.11111
# P(over|cat the) = 0.11111
# P(the|cat the) = 0.11111
# P(dog|cat the) = 0.11111
# P(.|cat the) = 0.11111
# P(the|cat the) = 0.11111
# P(dog|cat the) = 0.11111
# P(ran|cat the) = 0.11111
# P(on|cat the) = 0.11111
# P(the|cat the) = 0.11111
# P(floor|cat the) = 0.11111
# P(.|cat the) = 0.11111
# P(the|cat dog) = 0.11111
# P(cat|cat dog) = 0.11111
# P(jumped|cat dog) = 0.11111
# P(over|cat dog) = 0.11111
# P(the|cat dog) = 0.11111
# P(dog|cat dog) = 0.11111
# P(.|cat dog) = 0.11111
# P(the|cat dog) = 0.11111
# P(dog|cat dog) = 0.11111
# P(ran|cat dog) = 0.11111
# P(on|cat dog) = 0.11111
# P(the|cat dog) = 0.11111
# P(floor|cat dog) = 0.11111
# P(.|cat dog) = 0.11111
# P(the|cat ran) = 0.11111
# P(cat|cat ran) = 0.11111
# P(jumped|cat ran) = 0.11111
# P(over|cat ran) = 0.11111
# P(the|cat ran) = 0.11111
# P(dog|cat ran) = 0.11111
# P(.|cat ran) = 0.11111
# P(the|cat ran) = 0.11111
# P(dog|cat ran) = 0.11111
# P(ran|cat ran) = 0.11111
# P(on|cat ran) = 0.11111
# P(the|cat ran) = 0.11111
# P(floor|cat ran) = 0.11111
# P(.|cat ran) = 0.11111
# P(the|cat on) = 0.11111
# P(cat|cat on) = 0.11111
# P(jumped|cat on) = 0.11111
# P(over|cat on) = 0.11111
# P(the|cat on) = 0.11111
# P(dog|cat on) = 0.11111
# P(.|cat on) = 0.11111
# P(the|cat on) = 0.11111
# P(dog|cat on) = 0.11111
# P(ran|cat on) = 0.11111
# P(on|cat on) = 0.11111
# P(the|cat on) = 0.11111
# P(floor|cat on) = 0.11111
# P(.|cat on) = 0.11111
# P(the|cat the) = 0.11111
# P(cat|cat the) = 0.11111
# P(jumped|cat the) = 0.11111
# P(over|cat the) = 0.11111
# P(the|cat the) = 0.11111
# P(dog|cat the) = 0.11111
# P(.|cat the) = 0.11111
# P(the|cat the) = 0.11111
# P(dog|cat the) = 0.11111
# P(ran|cat the) = 0.11111
# P(on|cat the) = 0.11111
# P(the|cat the) = 0.11111
# P(floor|cat the) = 0.11111
# P(.|cat the) = 0.11111
# P(the|cat floor) = 0.11111
# P(cat|cat floor) = 0.11111
# P(jumped|cat floor) = 0.11111
# P(over|cat floor) = 0.11111
# P(the|cat floor) = 0.11111
# P(dog|cat floor) = 0.11111
# P(.|cat floor) = 0.11111
# P(the|cat floor) = 0.11111
# P(dog|cat floor) = 0.11111
# P(ran|cat floor) = 0.11111
# P(on|cat floor) = 0.11111
# P(the|cat floor) = 0.11111
# P(floor|cat floor) = 0.11111
# P(.|cat floor) = 0.11111
# P(the|cat .) = 0.11111
# P(cat|cat .) = 0.11111
# P(jumped|cat .) = 0.11111
# P(over|cat .) = 0.11111
# P(the|cat .) = 0.11111
# P(dog|cat .) = 0.11111
# P(.|cat .) = 0.11111
# P(the|cat .) = 0.11111
# P(dog|cat .) = 0.11111
# P(ran|cat .) = 0.11111
# P(on|cat .) = 0.11111
# P(the|cat .) = 0.11111
# P(floor|cat .) = 0.11111
# P(.|cat .) = 0.11111
# P(the|jumped the) = 0.11111
# P(cat|jumped the) = 0.11111
# P(jumped|jumped the) = 0.11111
# P(over|jumped the) = 0.11111
# P(the|jumped the) = 0.11111
# P(dog|jumped the) = 0.11111
# P(.|jumped the) = 0.11111
# P(the|jumped the) = 0.11111
# P(dog|jumped the) = 0.11111
# P(ran|jumped the) = 0.11111
# P(on|jumped the) = 0.11111
# P(the|jumped the) = 0.11111
# P(floor|jumped the) = 0.11111
# P(.|jumped the) = 0.11111
# P(the|jumped cat) = 0.11111
# P(cat|jumped cat) = 0.11111
# P(jumped|jumped cat) = 0.11111
# P(over|jumped cat) = 0.11111
# P(the|jumped cat) = 0.11111
# P(dog|jumped cat) = 0.11111
# P(.|jumped cat) = 0.11111
# P(the|jumped cat) = 0.11111
# P(dog|jumped cat) = 0.11111
# P(ran|jumped cat) = 0.11111
# P(on|jumped cat) = 0.11111
# P(the|jumped cat) = 0.11111
# P(floor|jumped cat) = 0.11111
# P(.|jumped cat) = 0.11111
# P(the|jumped jumped) = 0.11111
# P(cat|jumped jumped) = 0.11111
# P(jumped|jumped jumped) = 0.11111
# P(over|jumped jumped) = 0.11111
# P(the|jumped jumped) = 0.11111
# P(dog|jumped jumped) = 0.11111
# P(.|jumped jumped) = 0.11111
# P(the|jumped jumped) = 0.11111
# P(dog|jumped jumped) = 0.11111
# P(ran|jumped jumped) = 0.11111
# P(on|jumped jumped) = 0.11111
# P(the|jumped jumped) = 0.11111
# P(floor|jumped jumped) = 0.11111
# P(.|jumped jumped) = 0.11111
# P(the|jumped over) = 0.20000
# P(cat|jumped over) = 0.10000
# P(jumped|jumped over) = 0.10000
# P(over|jumped over) = 0.10000
# P(the|jumped over) = 0.20000
# P(dog|jumped over) = 0.10000
# P(.|jumped over) = 0.10000
# P(the|jumped over) = 0.20000
# P(dog|jumped over) = 0.10000
# P(ran|jumped over) = 0.10000
# P(on|jumped over) = 0.10000
# P(the|jumped over) = 0.20000
# P(floor|jumped over) = 0.10000
# P(.|jumped over) = 0.10000
# P(the|jumped the) = 0.11111
# P(cat|jumped the) = 0.11111
# P(jumped|jumped the) = 0.11111
# P(over|jumped the) = 0.11111
# P(the|jumped the) = 0.11111
# P(dog|jumped the) = 0.11111
# P(.|jumped the) = 0.11111
# P(the|jumped the) = 0.11111
# P(dog|jumped the) = 0.11111
# P(ran|jumped the) = 0.11111
# P(on|jumped the) = 0.11111
# P(the|jumped the) = 0.11111
# P(floor|jumped the) = 0.11111
# P(.|jumped the) = 0.11111
# P(the|jumped dog) = 0.11111
# P(cat|jumped dog) = 0.11111
# P(jumped|jumped dog) = 0.11111
# P(over|jumped dog) = 0.11111
# P(the|jumped dog) = 0.11111
# P(dog|jumped dog) = 0.11111
# P(.|jumped dog) = 0.11111
# P(the|jumped dog) = 0.11111
# P(dog|jumped dog) = 0.11111
# P(ran|jumped dog) = 0.11111
# P(on|jumped dog) = 0.11111
# P(the|jumped dog) = 0.11111
# P(floor|jumped dog) = 0.11111
# P(.|jumped dog) = 0.11111
# P(the|jumped .) = 0.11111
# P(cat|jumped .) = 0.11111
# P(jumped|jumped .) = 0.11111
# P(over|jumped .) = 0.11111
# P(the|jumped .) = 0.11111
# P(dog|jumped .) = 0.11111
# P(.|jumped .) = 0.11111
# P(the|jumped .) = 0.11111
# P(dog|jumped .) = 0.11111
# P(ran|jumped .) = 0.11111
# P(on|jumped .) = 0.11111
# P(the|jumped .) = 0.11111
# P(floor|jumped .) = 0.11111
# P(.|jumped .) = 0.11111
# P(the|jumped the) = 0.11111
# P(cat|jumped the) = 0.11111
# P(jumped|jumped the) = 0.11111
# P(over|jumped the) = 0.11111
# P(the|jumped the) = 0.11111
# P(dog|jumped the) = 0.11111
# P(.|jumped the) = 0.11111
# P(the|jumped the) = 0.11111
# P(dog|jumped the) = 0.11111
# P(ran|jumped the) = 0.11111
# P(on|jumped the) = 0.11111
# P(the|jumped the) = 0.11111
# P(floor|jumped the) = 0.11111
# P(.|jumped the) = 0.11111
# P(the|jumped dog) = 0.11111
# P(cat|jumped dog) = 0.11111
# P(jumped|jumped dog) = 0.11111
# P(over|jumped dog) = 0.11111
# P(the|jumped dog) = 0.11111
# P(dog|jumped dog) = 0.11111
# P(.|jumped dog) = 0.11111
# P(the|jumped dog) = 0.11111
# P(dog|jumped dog) = 0.11111
# P(ran|jumped dog) = 0.11111
# P(on|jumped dog) = 0.11111
# P(the|jumped dog) = 0.11111
# P(floor|jumped dog) = 0.11111
# P(.|jumped dog) = 0.11111
# P(the|jumped ran) = 0.11111
# P(cat|jumped ran) = 0.11111
# P(jumped|jumped ran) = 0.11111
# P(over|jumped ran) = 0.11111
# P(the|jumped ran) = 0.11111
# P(dog|jumped ran) = 0.11111
# P(.|jumped ran) = 0.11111
# P(the|jumped ran) = 0.11111
# P(dog|jumped ran) = 0.11111
# P(ran|jumped ran) = 0.11111
# P(on|jumped ran) = 0.11111
# P(the|jumped ran) = 0.11111
# P(floor|jumped ran) = 0.11111
# P(.|jumped ran) = 0.11111
# P(the|jumped on) = 0.11111
# P(cat|jumped on) = 0.11111
# P(jumped|jumped on) = 0.11111
# P(over|jumped on) = 0.11111
# P(the|jumped on) = 0.11111
# P(dog|jumped on) = 0.11111
# P(.|jumped on) = 0.11111
# P(the|jumped on) = 0.11111
# P(dog|jumped on) = 0.11111
# P(ran|jumped on) = 0.11111
# P(on|jumped on) = 0.11111
# P(the|jumped on) = 0.11111
# P(floor|jumped on) = 0.11111
# P(.|jumped on) = 0.11111
# P(the|jumped the) = 0.11111
# P(cat|jumped the) = 0.11111
# P(jumped|jumped the) = 0.11111
# P(over|jumped the) = 0.11111
# P(the|jumped the) = 0.11111
# P(dog|jumped the) = 0.11111
# P(.|jumped the) = 0.11111
# P(the|jumped the) = 0.11111
# P(dog|jumped the) = 0.11111
# P(ran|jumped the) = 0.11111
# P(on|jumped the) = 0.11111
# P(the|jumped the) = 0.11111
# P(floor|jumped the) = 0.11111
# P(.|jumped the) = 0.11111
# P(the|jumped floor) = 0.11111
# P(cat|jumped floor) = 0.11111
# P(jumped|jumped floor) = 0.11111
# P(over|jumped floor) = 0.11111
# P(the|jumped floor) = 0.11111
# P(dog|jumped floor) = 0.11111
# P(.|jumped floor) = 0.11111
# P(the|jumped floor) = 0.11111
# P(dog|jumped floor) = 0.11111
# P(ran|jumped floor) = 0.11111
# P(on|jumped floor) = 0.11111
# P(the|jumped floor) = 0.11111
# P(floor|jumped floor) = 0.11111
# P(.|jumped floor) = 0.11111
# P(the|jumped .) = 0.11111
# P(cat|jumped .) = 0.11111
# P(jumped|jumped .) = 0.11111
# P(over|jumped .) = 0.11111
# P(the|jumped .) = 0.11111
# P(dog|jumped .) = 0.11111
# P(.|jumped .) = 0.11111
# P(the|jumped .) = 0.11111
# P(dog|jumped .) = 0.11111
# P(ran|jumped .) = 0.11111
# P(on|jumped .) = 0.11111
# P(the|jumped .) = 0.11111
# P(floor|jumped .) = 0.11111
# P(.|jumped .) = 0.11111
# P(the|over the) = 0.10000
# P(cat|over the) = 0.10000
# P(jumped|over the) = 0.10000
# P(over|over the) = 0.10000
# P(the|over the) = 0.10000
# P(dog|over the) = 0.20000
# P(.|over the) = 0.10000
# P(the|over the) = 0.10000
# P(dog|over the) = 0.20000
# P(ran|over the) = 0.10000
# P(on|over the) = 0.10000
# P(the|over the) = 0.10000
# P(floor|over the) = 0.10000
# P(.|over the) = 0.10000
# P(the|over cat) = 0.11111
# P(cat|over cat) = 0.11111
# P(jumped|over cat) = 0.11111
# P(over|over cat) = 0.11111
# P(the|over cat) = 0.11111
# P(dog|over cat) = 0.11111
# P(.|over cat) = 0.11111
# P(the|over cat) = 0.11111
# P(dog|over cat) = 0.11111
# P(ran|over cat) = 0.11111
# P(on|over cat) = 0.11111
# P(the|over cat) = 0.11111
# P(floor|over cat) = 0.11111
# P(.|over cat) = 0.11111
# P(the|over jumped) = 0.11111
# P(cat|over jumped) = 0.11111
# P(jumped|over jumped) = 0.11111
# P(over|over jumped) = 0.11111
# P(the|over jumped) = 0.11111
# P(dog|over jumped) = 0.11111
# P(.|over jumped) = 0.11111
# P(the|over jumped) = 0.11111
# P(dog|over jumped) = 0.11111
# P(ran|over jumped) = 0.11111
# P(on|over jumped) = 0.11111
# P(the|over jumped) = 0.11111
# P(floor|over jumped) = 0.11111
# P(.|over jumped) = 0.11111
# P(the|over over) = 0.11111
# P(cat|over over) = 0.11111
# P(jumped|over over) = 0.11111
# P(over|over over) = 0.11111
# P(the|over over) = 0.11111
# P(dog|over over) = 0.11111
# P(.|over over) = 0.11111
# P(the|over over) = 0.11111
# P(dog|over over) = 0.11111
# P(ran|over over) = 0.11111
# P(on|over over) = 0.11111
# P(the|over over) = 0.11111
# P(floor|over over) = 0.11111
# P(.|over over) = 0.11111
# P(the|over the) = 0.10000
# P(cat|over the) = 0.10000
# P(jumped|over the) = 0.10000
# P(over|over the) = 0.10000
# P(the|over the) = 0.10000
# P(dog|over the) = 0.20000
# P(.|over the) = 0.10000
# P(the|over the) = 0.10000
# P(dog|over the) = 0.20000
# P(ran|over the) = 0.10000
# P(on|over the) = 0.10000
# P(the|over the) = 0.10000
# P(floor|over the) = 0.10000
# P(.|over the) = 0.10000
# P(the|over dog) = 0.11111
# P(cat|over dog) = 0.11111
# P(jumped|over dog) = 0.11111
# P(over|over dog) = 0.11111
# P(the|over dog) = 0.11111
# P(dog|over dog) = 0.11111
# P(.|over dog) = 0.11111
# P(the|over dog) = 0.11111
# P(dog|over dog) = 0.11111
# P(ran|over dog) = 0.11111
# P(on|over dog) = 0.11111
# P(the|over dog) = 0.11111
# P(floor|over dog) = 0.11111
# P(.|over dog) = 0.11111
# P(the|over .) = 0.11111
# P(cat|over .) = 0.11111
# P(jumped|over .) = 0.11111
# P(over|over .) = 0.11111
# P(the|over .) = 0.11111
# P(dog|over .) = 0.11111
# P(.|over .) = 0.11111
# P(the|over .) = 0.11111
# P(dog|over .) = 0.11111
# P(ran|over .) = 0.11111
# P(on|over .) = 0.11111
# P(the|over .) = 0.11111
# P(floor|over .) = 0.11111
# P(.|over .) = 0.11111
# P(the|over the) = 0.10000
# P(cat|over the) = 0.10000
# P(jumped|over the) = 0.10000
# P(over|over the) = 0.10000
# P(the|over the) = 0.10000
# P(dog|over the) = 0.20000
# P(.|over the) = 0.10000
# P(the|over the) = 0.10000
# P(dog|over the) = 0.20000
# P(ran|over the) = 0.10000
# P(on|over the) = 0.10000
# P(the|over the) = 0.10000
# P(floor|over the) = 0.10000
# P(.|over the) = 0.10000
# P(the|over dog) = 0.11111
# P(cat|over dog) = 0.11111
# P(jumped|over dog) = 0.11111
# P(over|over dog) = 0.11111
# P(the|over dog) = 0.11111
# P(dog|over dog) = 0.11111
# P(.|over dog) = 0.11111
# P(the|over dog) = 0.11111
# P(dog|over dog) = 0.11111
# P(ran|over dog) = 0.11111
# P(on|over dog) = 0.11111
# P(the|over dog) = 0.11111
# P(floor|over dog) = 0.11111
# P(.|over dog) = 0.11111
# P(the|over ran) = 0.11111
# P(cat|over ran) = 0.11111
# P(jumped|over ran) = 0.11111
# P(over|over ran) = 0.11111
# P(the|over ran) = 0.11111
# P(dog|over ran) = 0.11111
# P(.|over ran) = 0.11111
# P(the|over ran) = 0.11111
# P(dog|over ran) = 0.11111
# P(ran|over ran) = 0.11111
# P(on|over ran) = 0.11111
# P(the|over ran) = 0.11111
# P(floor|over ran) = 0.11111
# P(.|over ran) = 0.11111
# P(the|over on) = 0.11111
# P(cat|over on) = 0.11111
# P(jumped|over on) = 0.11111
# P(over|over on) = 0.11111
# P(the|over on) = 0.11111
# P(dog|over on) = 0.11111
# P(.|over on) = 0.11111
# P(the|over on) = 0.11111
# P(dog|over on) = 0.11111
# P(ran|over on) = 0.11111
# P(on|over on) = 0.11111
# P(the|over on) = 0.11111
# P(floor|over on) = 0.11111
# P(.|over on) = 0.11111
# P(the|over the) = 0.10000
# P(cat|over the) = 0.10000
# P(jumped|over the) = 0.10000
# P(over|over the) = 0.10000
# P(the|over the) = 0.10000
# P(dog|over the) = 0.20000
# P(.|over the) = 0.10000
# P(the|over the) = 0.10000
# P(dog|over the) = 0.20000
# P(ran|over the) = 0.10000
# P(on|over the) = 0.10000
# P(the|over the) = 0.10000
# P(floor|over the) = 0.10000
# P(.|over the) = 0.10000
# P(the|over floor) = 0.11111
# P(cat|over floor) = 0.11111
# P(jumped|over floor) = 0.11111
# P(over|over floor) = 0.11111
# P(the|over floor) = 0.11111
# P(dog|over floor) = 0.11111
# P(.|over floor) = 0.11111
# P(the|over floor) = 0.11111
# P(dog|over floor) = 0.11111
# P(ran|over floor) = 0.11111
# P(on|over floor) = 0.11111
# P(the|over floor) = 0.11111
# P(floor|over floor) = 0.11111
# P(.|over floor) = 0.11111
# P(the|over .) = 0.11111
# P(cat|over .) = 0.11111
# P(jumped|over .) = 0.11111
# P(over|over .) = 0.11111
# P(the|over .) = 0.11111
# P(dog|over .) = 0.11111
# P(.|over .) = 0.11111
# P(the|over .) = 0.11111
# P(dog|over .) = 0.11111
# P(ran|over .) = 0.11111
# P(on|over .) = 0.11111
# P(the|over .) = 0.11111
# P(floor|over .) = 0.11111
# P(.|over .) = 0.11111
# P(the|the the) = 0.11111
# P(cat|the the) = 0.11111
# P(jumped|the the) = 0.11111
# P(over|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(ran|the the) = 0.11111
# P(on|the the) = 0.11111
# P(the|the the) = 0.11111
# P(floor|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the cat) = 0.10000
# P(cat|the cat) = 0.10000
# P(jumped|the cat) = 0.20000
# P(over|the cat) = 0.10000
# P(the|the cat) = 0.10000
# P(dog|the cat) = 0.10000
# P(.|the cat) = 0.10000
# P(the|the cat) = 0.10000
# P(dog|the cat) = 0.10000
# P(ran|the cat) = 0.10000
# P(on|the cat) = 0.10000
# P(the|the cat) = 0.10000
# P(floor|the cat) = 0.10000
# P(.|the cat) = 0.10000
# P(the|the jumped) = 0.11111
# P(cat|the jumped) = 0.11111
# P(jumped|the jumped) = 0.11111
# P(over|the jumped) = 0.11111
# P(the|the jumped) = 0.11111
# P(dog|the jumped) = 0.11111
# P(.|the jumped) = 0.11111
# P(the|the jumped) = 0.11111
# P(dog|the jumped) = 0.11111
# P(ran|the jumped) = 0.11111
# P(on|the jumped) = 0.11111
# P(the|the jumped) = 0.11111
# P(floor|the jumped) = 0.11111
# P(.|the jumped) = 0.11111
# P(the|the over) = 0.11111
# P(cat|the over) = 0.11111
# P(jumped|the over) = 0.11111
# P(over|the over) = 0.11111
# P(the|the over) = 0.11111
# P(dog|the over) = 0.11111
# P(.|the over) = 0.11111
# P(the|the over) = 0.11111
# P(dog|the over) = 0.11111
# P(ran|the over) = 0.11111
# P(on|the over) = 0.11111
# P(the|the over) = 0.11111
# P(floor|the over) = 0.11111
# P(.|the over) = 0.11111
# P(the|the the) = 0.11111
# P(cat|the the) = 0.11111
# P(jumped|the the) = 0.11111
# P(over|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(ran|the the) = 0.11111
# P(on|the the) = 0.11111
# P(the|the the) = 0.11111
# P(floor|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the dog) = 0.09091
# P(cat|the dog) = 0.09091
# P(jumped|the dog) = 0.09091
# P(over|the dog) = 0.09091
# P(the|the dog) = 0.09091
# P(dog|the dog) = 0.09091
# P(.|the dog) = 0.18182
# P(the|the dog) = 0.09091
# P(dog|the dog) = 0.09091
# P(ran|the dog) = 0.18182
# P(on|the dog) = 0.09091
# P(the|the dog) = 0.09091
# P(floor|the dog) = 0.09091
# P(.|the dog) = 0.18182
# P(the|the .) = 0.11111
# P(cat|the .) = 0.11111
# P(jumped|the .) = 0.11111
# P(over|the .) = 0.11111
# P(the|the .) = 0.11111
# P(dog|the .) = 0.11111
# P(.|the .) = 0.11111
# P(the|the .) = 0.11111
# P(dog|the .) = 0.11111
# P(ran|the .) = 0.11111
# P(on|the .) = 0.11111
# P(the|the .) = 0.11111
# P(floor|the .) = 0.11111
# P(.|the .) = 0.11111
# P(the|the the) = 0.11111
# P(cat|the the) = 0.11111
# P(jumped|the the) = 0.11111
# P(over|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(ran|the the) = 0.11111
# P(on|the the) = 0.11111
# P(the|the the) = 0.11111
# P(floor|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the dog) = 0.09091
# P(cat|the dog) = 0.09091
# P(jumped|the dog) = 0.09091
# P(over|the dog) = 0.09091
# P(the|the dog) = 0.09091
# P(dog|the dog) = 0.09091
# P(.|the dog) = 0.18182
# P(the|the dog) = 0.09091
# P(dog|the dog) = 0.09091
# P(ran|the dog) = 0.18182
# P(on|the dog) = 0.09091
# P(the|the dog) = 0.09091
# P(floor|the dog) = 0.09091
# P(.|the dog) = 0.18182
# P(the|the ran) = 0.11111
# P(cat|the ran) = 0.11111
# P(jumped|the ran) = 0.11111
# P(over|the ran) = 0.11111
# P(the|the ran) = 0.11111
# P(dog|the ran) = 0.11111
# P(.|the ran) = 0.11111
# P(the|the ran) = 0.11111
# P(dog|the ran) = 0.11111
# P(ran|the ran) = 0.11111
# P(on|the ran) = 0.11111
# P(the|the ran) = 0.11111
# P(floor|the ran) = 0.11111
# P(.|the ran) = 0.11111
# P(the|the on) = 0.11111
# P(cat|the on) = 0.11111
# P(jumped|the on) = 0.11111
# P(over|the on) = 0.11111
# P(the|the on) = 0.11111
# P(dog|the on) = 0.11111
# P(.|the on) = 0.11111
# P(the|the on) = 0.11111
# P(dog|the on) = 0.11111
# P(ran|the on) = 0.11111
# P(on|the on) = 0.11111
# P(the|the on) = 0.11111
# P(floor|the on) = 0.11111
# P(.|the on) = 0.11111
# P(the|the the) = 0.11111
# P(cat|the the) = 0.11111
# P(jumped|the the) = 0.11111
# P(over|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(ran|the the) = 0.11111
# P(on|the the) = 0.11111
# P(the|the the) = 0.11111
# P(floor|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the floor) = 0.10000
# P(cat|the floor) = 0.10000
# P(jumped|the floor) = 0.10000
# P(over|the floor) = 0.10000
# P(the|the floor) = 0.10000
# P(dog|the floor) = 0.10000
# P(.|the floor) = 0.20000
# P(the|the floor) = 0.10000
# P(dog|the floor) = 0.10000
# P(ran|the floor) = 0.10000
# P(on|the floor) = 0.10000
# P(the|the floor) = 0.10000
# P(floor|the floor) = 0.10000
# P(.|the floor) = 0.20000
# P(the|the .) = 0.11111
# P(cat|the .) = 0.11111
# P(jumped|the .) = 0.11111
# P(over|the .) = 0.11111
# P(the|the .) = 0.11111
# P(dog|the .) = 0.11111
# P(.|the .) = 0.11111
# P(the|the .) = 0.11111
# P(dog|the .) = 0.11111
# P(ran|the .) = 0.11111
# P(on|the .) = 0.11111
# P(the|the .) = 0.11111
# P(floor|the .) = 0.11111
# P(.|the .) = 0.11111
# P(the|dog the) = 0.11111
# P(cat|dog the) = 0.11111
# P(jumped|dog the) = 0.11111
# P(over|dog the) = 0.11111
# P(the|dog the) = 0.11111
# P(dog|dog the) = 0.11111
# P(.|dog the) = 0.11111
# P(the|dog the) = 0.11111
# P(dog|dog the) = 0.11111
# P(ran|dog the) = 0.11111
# P(on|dog the) = 0.11111
# P(the|dog the) = 0.11111
# P(floor|dog the) = 0.11111
# P(.|dog the) = 0.11111
# P(the|dog cat) = 0.11111
# P(cat|dog cat) = 0.11111
# P(jumped|dog cat) = 0.11111
# P(over|dog cat) = 0.11111
# P(the|dog cat) = 0.11111
# P(dog|dog cat) = 0.11111
# P(.|dog cat) = 0.11111
# P(the|dog cat) = 0.11111
# P(dog|dog cat) = 0.11111
# P(ran|dog cat) = 0.11111
# P(on|dog cat) = 0.11111
# P(the|dog cat) = 0.11111
# P(floor|dog cat) = 0.11111
# P(.|dog cat) = 0.11111
# P(the|dog jumped) = 0.11111
# P(cat|dog jumped) = 0.11111
# P(jumped|dog jumped) = 0.11111
# P(over|dog jumped) = 0.11111
# P(the|dog jumped) = 0.11111
# P(dog|dog jumped) = 0.11111
# P(.|dog jumped) = 0.11111
# P(the|dog jumped) = 0.11111
# P(dog|dog jumped) = 0.11111
# P(ran|dog jumped) = 0.11111
# P(on|dog jumped) = 0.11111
# P(the|dog jumped) = 0.11111
# P(floor|dog jumped) = 0.11111
# P(.|dog jumped) = 0.11111
# P(the|dog over) = 0.11111
# P(cat|dog over) = 0.11111
# P(jumped|dog over) = 0.11111
# P(over|dog over) = 0.11111
# P(the|dog over) = 0.11111
# P(dog|dog over) = 0.11111
# P(.|dog over) = 0.11111
# P(the|dog over) = 0.11111
# P(dog|dog over) = 0.11111
# P(ran|dog over) = 0.11111
# P(on|dog over) = 0.11111
# P(the|dog over) = 0.11111
# P(floor|dog over) = 0.11111
# P(.|dog over) = 0.11111
# P(the|dog the) = 0.11111
# P(cat|dog the) = 0.11111
# P(jumped|dog the) = 0.11111
# P(over|dog the) = 0.11111
# P(the|dog the) = 0.11111
# P(dog|dog the) = 0.11111
# P(.|dog the) = 0.11111
# P(the|dog the) = 0.11111
# P(dog|dog the) = 0.11111
# P(ran|dog the) = 0.11111
# P(on|dog the) = 0.11111
# P(the|dog the) = 0.11111
# P(floor|dog the) = 0.11111
# P(.|dog the) = 0.11111
# P(the|dog dog) = 0.11111
# P(cat|dog dog) = 0.11111
# P(jumped|dog dog) = 0.11111
# P(over|dog dog) = 0.11111
# P(the|dog dog) = 0.11111
# P(dog|dog dog) = 0.11111
# P(.|dog dog) = 0.11111
# P(the|dog dog) = 0.11111
# P(dog|dog dog) = 0.11111
# P(ran|dog dog) = 0.11111
# P(on|dog dog) = 0.11111
# P(the|dog dog) = 0.11111
# P(floor|dog dog) = 0.11111
# P(.|dog dog) = 0.11111
# P(the|dog .) = 0.20000
# P(cat|dog .) = 0.10000
# P(jumped|dog .) = 0.10000
# P(over|dog .) = 0.10000
# P(the|dog .) = 0.20000
# P(dog|dog .) = 0.10000
# P(.|dog .) = 0.10000
# P(the|dog .) = 0.20000
# P(dog|dog .) = 0.10000
# P(ran|dog .) = 0.10000
# P(on|dog .) = 0.10000
# P(the|dog .) = 0.20000
# P(floor|dog .) = 0.10000
# P(.|dog .) = 0.10000
# P(the|dog the) = 0.11111
# P(cat|dog the) = 0.11111
# P(jumped|dog the) = 0.11111
# P(over|dog the) = 0.11111
# P(the|dog the) = 0.11111
# P(dog|dog the) = 0.11111
# P(.|dog the) = 0.11111
# P(the|dog the) = 0.11111
# P(dog|dog the) = 0.11111
# P(ran|dog the) = 0.11111
# P(on|dog the) = 0.11111
# P(the|dog the) = 0.11111
# P(floor|dog the) = 0.11111
# P(.|dog the) = 0.11111
# P(the|dog dog) = 0.11111
# P(cat|dog dog) = 0.11111
# P(jumped|dog dog) = 0.11111
# P(over|dog dog) = 0.11111
# P(the|dog dog) = 0.11111
# P(dog|dog dog) = 0.11111
# P(.|dog dog) = 0.11111
# P(the|dog dog) = 0.11111
# P(dog|dog dog) = 0.11111
# P(ran|dog dog) = 0.11111
# P(on|dog dog) = 0.11111
# P(the|dog dog) = 0.11111
# P(floor|dog dog) = 0.11111
# P(.|dog dog) = 0.11111
# P(the|dog ran) = 0.10000
# P(cat|dog ran) = 0.10000
# P(jumped|dog ran) = 0.10000
# P(over|dog ran) = 0.10000
# P(the|dog ran) = 0.10000
# P(dog|dog ran) = 0.10000
# P(.|dog ran) = 0.10000
# P(the|dog ran) = 0.10000
# P(dog|dog ran) = 0.10000
# P(ran|dog ran) = 0.10000
# P(on|dog ran) = 0.20000
# P(the|dog ran) = 0.10000
# P(floor|dog ran) = 0.10000
# P(.|dog ran) = 0.10000
# P(the|dog on) = 0.11111
# P(cat|dog on) = 0.11111
# P(jumped|dog on) = 0.11111
# P(over|dog on) = 0.11111
# P(the|dog on) = 0.11111
# P(dog|dog on) = 0.11111
# P(.|dog on) = 0.11111
# P(the|dog on) = 0.11111
# P(dog|dog on) = 0.11111
# P(ran|dog on) = 0.11111
# P(on|dog on) = 0.11111
# P(the|dog on) = 0.11111
# P(floor|dog on) = 0.11111
# P(.|dog on) = 0.11111
# P(the|dog the) = 0.11111
# P(cat|dog the) = 0.11111
# P(jumped|dog the) = 0.11111
# P(over|dog the) = 0.11111
# P(the|dog the) = 0.11111
# P(dog|dog the) = 0.11111
# P(.|dog the) = 0.11111
# P(the|dog the) = 0.11111
# P(dog|dog the) = 0.11111
# P(ran|dog the) = 0.11111
# P(on|dog the) = 0.11111
# P(the|dog the) = 0.11111
# P(floor|dog the) = 0.11111
# P(.|dog the) = 0.11111
# P(the|dog floor) = 0.11111
# P(cat|dog floor) = 0.11111
# P(jumped|dog floor) = 0.11111
# P(over|dog floor) = 0.11111
# P(the|dog floor) = 0.11111
# P(dog|dog floor) = 0.11111
# P(.|dog floor) = 0.11111
# P(the|dog floor) = 0.11111
# P(dog|dog floor) = 0.11111
# P(ran|dog floor) = 0.11111
# P(on|dog floor) = 0.11111
# P(the|dog floor) = 0.11111
# P(floor|dog floor) = 0.11111
# P(.|dog floor) = 0.11111
# P(the|dog .) = 0.20000
# P(cat|dog .) = 0.10000
# P(jumped|dog .) = 0.10000
# P(over|dog .) = 0.10000
# P(the|dog .) = 0.20000
# P(dog|dog .) = 0.10000
# P(.|dog .) = 0.10000
# P(the|dog .) = 0.20000
# P(dog|dog .) = 0.10000
# P(ran|dog .) = 0.10000
# P(on|dog .) = 0.10000
# P(the|dog .) = 0.20000
# P(floor|dog .) = 0.10000
# P(.|dog .) = 0.10000
# P(the|. the) = 0.10000
# P(cat|. the) = 0.10000
# P(jumped|. the) = 0.10000
# P(over|. the) = 0.10000
# P(the|. the) = 0.10000
# P(dog|. the) = 0.20000
# P(.|. the) = 0.10000
# P(the|. the) = 0.10000
# P(dog|. the) = 0.20000
# P(ran|. the) = 0.10000
# P(on|. the) = 0.10000
# P(the|. the) = 0.10000
# P(floor|. the) = 0.10000
# P(.|. the) = 0.10000
# P(the|. cat) = 0.11111
# P(cat|. cat) = 0.11111
# P(jumped|. cat) = 0.11111
# P(over|. cat) = 0.11111
# P(the|. cat) = 0.11111
# P(dog|. cat) = 0.11111
# P(.|. cat) = 0.11111
# P(the|. cat) = 0.11111
# P(dog|. cat) = 0.11111
# P(ran|. cat) = 0.11111
# P(on|. cat) = 0.11111
# P(the|. cat) = 0.11111
# P(floor|. cat) = 0.11111
# P(.|. cat) = 0.11111
# P(the|. jumped) = 0.11111
# P(cat|. jumped) = 0.11111
# P(jumped|. jumped) = 0.11111
# P(over|. jumped) = 0.11111
# P(the|. jumped) = 0.11111
# P(dog|. jumped) = 0.11111
# P(.|. jumped) = 0.11111
# P(the|. jumped) = 0.11111
# P(dog|. jumped) = 0.11111
# P(ran|. jumped) = 0.11111
# P(on|. jumped) = 0.11111
# P(the|. jumped) = 0.11111
# P(floor|. jumped) = 0.11111
# P(.|. jumped) = 0.11111
# P(the|. over) = 0.11111
# P(cat|. over) = 0.11111
# P(jumped|. over) = 0.11111
# P(over|. over) = 0.11111
# P(the|. over) = 0.11111
# P(dog|. over) = 0.11111
# P(.|. over) = 0.11111
# P(the|. over) = 0.11111
# P(dog|. over) = 0.11111
# P(ran|. over) = 0.11111
# P(on|. over) = 0.11111
# P(the|. over) = 0.11111
# P(floor|. over) = 0.11111
# P(.|. over) = 0.11111
# P(the|. the) = 0.10000
# P(cat|. the) = 0.10000
# P(jumped|. the) = 0.10000
# P(over|. the) = 0.10000
# P(the|. the) = 0.10000
# P(dog|. the) = 0.20000
# P(.|. the) = 0.10000
# P(the|. the) = 0.10000
# P(dog|. the) = 0.20000
# P(ran|. the) = 0.10000
# P(on|. the) = 0.10000
# P(the|. the) = 0.10000
# P(floor|. the) = 0.10000
# P(.|. the) = 0.10000
# P(the|. dog) = 0.11111
# P(cat|. dog) = 0.11111
# P(jumped|. dog) = 0.11111
# P(over|. dog) = 0.11111
# P(the|. dog) = 0.11111
# P(dog|. dog) = 0.11111
# P(.|. dog) = 0.11111
# P(the|. dog) = 0.11111
# P(dog|. dog) = 0.11111
# P(ran|. dog) = 0.11111
# P(on|. dog) = 0.11111
# P(the|. dog) = 0.11111
# P(floor|. dog) = 0.11111
# P(.|. dog) = 0.11111
# P(the|. .) = 0.11111
# P(cat|. .) = 0.11111
# P(jumped|. .) = 0.11111
# P(over|. .) = 0.11111
# P(the|. .) = 0.11111
# P(dog|. .) = 0.11111
# P(.|. .) = 0.11111
# P(the|. .) = 0.11111
# P(dog|. .) = 0.11111
# P(ran|. .) = 0.11111
# P(on|. .) = 0.11111
# P(the|. .) = 0.11111
# P(floor|. .) = 0.11111
# P(.|. .) = 0.11111
# P(the|. the) = 0.10000
# P(cat|. the) = 0.10000
# P(jumped|. the) = 0.10000
# P(over|. the) = 0.10000
# P(the|. the) = 0.10000
# P(dog|. the) = 0.20000
# P(.|. the) = 0.10000
# P(the|. the) = 0.10000
# P(dog|. the) = 0.20000
# P(ran|. the) = 0.10000
# P(on|. the) = 0.10000
# P(the|. the) = 0.10000
# P(floor|. the) = 0.10000
# P(.|. the) = 0.10000
# P(the|. dog) = 0.11111
# P(cat|. dog) = 0.11111
# P(jumped|. dog) = 0.11111
# P(over|. dog) = 0.11111
# P(the|. dog) = 0.11111
# P(dog|. dog) = 0.11111
# P(.|. dog) = 0.11111
# P(the|. dog) = 0.11111
# P(dog|. dog) = 0.11111
# P(ran|. dog) = 0.11111
# P(on|. dog) = 0.11111
# P(the|. dog) = 0.11111
# P(floor|. dog) = 0.11111
# P(.|. dog) = 0.11111
# P(the|. ran) = 0.11111
# P(cat|. ran) = 0.11111
# P(jumped|. ran) = 0.11111
# P(over|. ran) = 0.11111
# P(the|. ran) = 0.11111
# P(dog|. ran) = 0.11111
# P(.|. ran) = 0.11111
# P(the|. ran) = 0.11111
# P(dog|. ran) = 0.11111
# P(ran|. ran) = 0.11111
# P(on|. ran) = 0.11111
# P(the|. ran) = 0.11111
# P(floor|. ran) = 0.11111
# P(.|. ran) = 0.11111
# P(the|. on) = 0.11111
# P(cat|. on) = 0.11111
# P(jumped|. on) = 0.11111
# P(over|. on) = 0.11111
# P(the|. on) = 0.11111
# P(dog|. on) = 0.11111
# P(.|. on) = 0.11111
# P(the|. on) = 0.11111
# P(dog|. on) = 0.11111
# P(ran|. on) = 0.11111
# P(on|. on) = 0.11111
# P(the|. on) = 0.11111
# P(floor|. on) = 0.11111
# P(.|. on) = 0.11111
# P(the|. the) = 0.10000
# P(cat|. the) = 0.10000
# P(jumped|. the) = 0.10000
# P(over|. the) = 0.10000
# P(the|. the) = 0.10000
# P(dog|. the) = 0.20000
# P(.|. the) = 0.10000
# P(the|. the) = 0.10000
# P(dog|. the) = 0.20000
# P(ran|. the) = 0.10000
# P(on|. the) = 0.10000
# P(the|. the) = 0.10000
# P(floor|. the) = 0.10000
# P(.|. the) = 0.10000
# P(the|. floor) = 0.11111
# P(cat|. floor) = 0.11111
# P(jumped|. floor) = 0.11111
# P(over|. floor) = 0.11111
# P(the|. floor) = 0.11111
# P(dog|. floor) = 0.11111
# P(.|. floor) = 0.11111
# P(the|. floor) = 0.11111
# P(dog|. floor) = 0.11111
# P(ran|. floor) = 0.11111
# P(on|. floor) = 0.11111
# P(the|. floor) = 0.11111
# P(floor|. floor) = 0.11111
# P(.|. floor) = 0.11111
# P(the|. .) = 0.11111
# P(cat|. .) = 0.11111
# P(jumped|. .) = 0.11111
# P(over|. .) = 0.11111
# P(the|. .) = 0.11111
# P(dog|. .) = 0.11111
# P(.|. .) = 0.11111
# P(the|. .) = 0.11111
# P(dog|. .) = 0.11111
# P(ran|. .) = 0.11111
# P(on|. .) = 0.11111
# P(the|. .) = 0.11111
# P(floor|. .) = 0.11111
# P(.|. .) = 0.11111
# P(the|the the) = 0.11111
# P(cat|the the) = 0.11111
# P(jumped|the the) = 0.11111
# P(over|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(ran|the the) = 0.11111
# P(on|the the) = 0.11111
# P(the|the the) = 0.11111
# P(floor|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the cat) = 0.10000
# P(cat|the cat) = 0.10000
# P(jumped|the cat) = 0.20000
# P(over|the cat) = 0.10000
# P(the|the cat) = 0.10000
# P(dog|the cat) = 0.10000
# P(.|the cat) = 0.10000
# P(the|the cat) = 0.10000
# P(dog|the cat) = 0.10000
# P(ran|the cat) = 0.10000
# P(on|the cat) = 0.10000
# P(the|the cat) = 0.10000
# P(floor|the cat) = 0.10000
# P(.|the cat) = 0.10000
# P(the|the jumped) = 0.11111
# P(cat|the jumped) = 0.11111
# P(jumped|the jumped) = 0.11111
# P(over|the jumped) = 0.11111
# P(the|the jumped) = 0.11111
# P(dog|the jumped) = 0.11111
# P(.|the jumped) = 0.11111
# P(the|the jumped) = 0.11111
# P(dog|the jumped) = 0.11111
# P(ran|the jumped) = 0.11111
# P(on|the jumped) = 0.11111
# P(the|the jumped) = 0.11111
# P(floor|the jumped) = 0.11111
# P(.|the jumped) = 0.11111
# P(the|the over) = 0.11111
# P(cat|the over) = 0.11111
# P(jumped|the over) = 0.11111
# P(over|the over) = 0.11111
# P(the|the over) = 0.11111
# P(dog|the over) = 0.11111
# P(.|the over) = 0.11111
# P(the|the over) = 0.11111
# P(dog|the over) = 0.11111
# P(ran|the over) = 0.11111
# P(on|the over) = 0.11111
# P(the|the over) = 0.11111
# P(floor|the over) = 0.11111
# P(.|the over) = 0.11111
# P(the|the the) = 0.11111
# P(cat|the the) = 0.11111
# P(jumped|the the) = 0.11111
# P(over|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(ran|the the) = 0.11111
# P(on|the the) = 0.11111
# P(the|the the) = 0.11111
# P(floor|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the dog) = 0.09091
# P(cat|the dog) = 0.09091
# P(jumped|the dog) = 0.09091
# P(over|the dog) = 0.09091
# P(the|the dog) = 0.09091
# P(dog|the dog) = 0.09091
# P(.|the dog) = 0.18182
# P(the|the dog) = 0.09091
# P(dog|the dog) = 0.09091
# P(ran|the dog) = 0.18182
# P(on|the dog) = 0.09091
# P(the|the dog) = 0.09091
# P(floor|the dog) = 0.09091
# P(.|the dog) = 0.18182
# P(the|the .) = 0.11111
# P(cat|the .) = 0.11111
# P(jumped|the .) = 0.11111
# P(over|the .) = 0.11111
# P(the|the .) = 0.11111
# P(dog|the .) = 0.11111
# P(.|the .) = 0.11111
# P(the|the .) = 0.11111
# P(dog|the .) = 0.11111
# P(ran|the .) = 0.11111
# P(on|the .) = 0.11111
# P(the|the .) = 0.11111
# P(floor|the .) = 0.11111
# P(.|the .) = 0.11111
# P(the|the the) = 0.11111
# P(cat|the the) = 0.11111
# P(jumped|the the) = 0.11111
# P(over|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(ran|the the) = 0.11111
# P(on|the the) = 0.11111
# P(the|the the) = 0.11111
# P(floor|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the dog) = 0.09091
# P(cat|the dog) = 0.09091
# P(jumped|the dog) = 0.09091
# P(over|the dog) = 0.09091
# P(the|the dog) = 0.09091
# P(dog|the dog) = 0.09091
# P(.|the dog) = 0.18182
# P(the|the dog) = 0.09091
# P(dog|the dog) = 0.09091
# P(ran|the dog) = 0.18182
# P(on|the dog) = 0.09091
# P(the|the dog) = 0.09091
# P(floor|the dog) = 0.09091
# P(.|the dog) = 0.18182
# P(the|the ran) = 0.11111
# P(cat|the ran) = 0.11111
# P(jumped|the ran) = 0.11111
# P(over|the ran) = 0.11111
# P(the|the ran) = 0.11111
# P(dog|the ran) = 0.11111
# P(.|the ran) = 0.11111
# P(the|the ran) = 0.11111
# P(dog|the ran) = 0.11111
# P(ran|the ran) = 0.11111
# P(on|the ran) = 0.11111
# P(the|the ran) = 0.11111
# P(floor|the ran) = 0.11111
# P(.|the ran) = 0.11111
# P(the|the on) = 0.11111
# P(cat|the on) = 0.11111
# P(jumped|the on) = 0.11111
# P(over|the on) = 0.11111
# P(the|the on) = 0.11111
# P(dog|the on) = 0.11111
# P(.|the on) = 0.11111
# P(the|the on) = 0.11111
# P(dog|the on) = 0.11111
# P(ran|the on) = 0.11111
# P(on|the on) = 0.11111
# P(the|the on) = 0.11111
# P(floor|the on) = 0.11111
# P(.|the on) = 0.11111
# P(the|the the) = 0.11111
# P(cat|the the) = 0.11111
# P(jumped|the the) = 0.11111
# P(over|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(ran|the the) = 0.11111
# P(on|the the) = 0.11111
# P(the|the the) = 0.11111
# P(floor|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the floor) = 0.10000
# P(cat|the floor) = 0.10000
# P(jumped|the floor) = 0.10000
# P(over|the floor) = 0.10000
# P(the|the floor) = 0.10000
# P(dog|the floor) = 0.10000
# P(.|the floor) = 0.20000
# P(the|the floor) = 0.10000
# P(dog|the floor) = 0.10000
# P(ran|the floor) = 0.10000
# P(on|the floor) = 0.10000
# P(the|the floor) = 0.10000
# P(floor|the floor) = 0.10000
# P(.|the floor) = 0.20000
# P(the|the .) = 0.11111
# P(cat|the .) = 0.11111
# P(jumped|the .) = 0.11111
# P(over|the .) = 0.11111
# P(the|the .) = 0.11111
# P(dog|the .) = 0.11111
# P(.|the .) = 0.11111
# P(the|the .) = 0.11111
# P(dog|the .) = 0.11111
# P(ran|the .) = 0.11111
# P(on|the .) = 0.11111
# P(the|the .) = 0.11111
# P(floor|the .) = 0.11111
# P(.|the .) = 0.11111
# P(the|dog the) = 0.11111
# P(cat|dog the) = 0.11111
# P(jumped|dog the) = 0.11111
# P(over|dog the) = 0.11111
# P(the|dog the) = 0.11111
# P(dog|dog the) = 0.11111
# P(.|dog the) = 0.11111
# P(the|dog the) = 0.11111
# P(dog|dog the) = 0.11111
# P(ran|dog the) = 0.11111
# P(on|dog the) = 0.11111
# P(the|dog the) = 0.11111
# P(floor|dog the) = 0.11111
# P(.|dog the) = 0.11111
# P(the|dog cat) = 0.11111
# P(cat|dog cat) = 0.11111
# P(jumped|dog cat) = 0.11111
# P(over|dog cat) = 0.11111
# P(the|dog cat) = 0.11111
# P(dog|dog cat) = 0.11111
# P(.|dog cat) = 0.11111
# P(the|dog cat) = 0.11111
# P(dog|dog cat) = 0.11111
# P(ran|dog cat) = 0.11111
# P(on|dog cat) = 0.11111
# P(the|dog cat) = 0.11111
# P(floor|dog cat) = 0.11111
# P(.|dog cat) = 0.11111
# P(the|dog jumped) = 0.11111
# P(cat|dog jumped) = 0.11111
# P(jumped|dog jumped) = 0.11111
# P(over|dog jumped) = 0.11111
# P(the|dog jumped) = 0.11111
# P(dog|dog jumped) = 0.11111
# P(.|dog jumped) = 0.11111
# P(the|dog jumped) = 0.11111
# P(dog|dog jumped) = 0.11111
# P(ran|dog jumped) = 0.11111
# P(on|dog jumped) = 0.11111
# P(the|dog jumped) = 0.11111
# P(floor|dog jumped) = 0.11111
# P(.|dog jumped) = 0.11111
# P(the|dog over) = 0.11111
# P(cat|dog over) = 0.11111
# P(jumped|dog over) = 0.11111
# P(over|dog over) = 0.11111
# P(the|dog over) = 0.11111
# P(dog|dog over) = 0.11111
# P(.|dog over) = 0.11111
# P(the|dog over) = 0.11111
# P(dog|dog over) = 0.11111
# P(ran|dog over) = 0.11111
# P(on|dog over) = 0.11111
# P(the|dog over) = 0.11111
# P(floor|dog over) = 0.11111
# P(.|dog over) = 0.11111
# P(the|dog the) = 0.11111
# P(cat|dog the) = 0.11111
# P(jumped|dog the) = 0.11111
# P(over|dog the) = 0.11111
# P(the|dog the) = 0.11111
# P(dog|dog the) = 0.11111
# P(.|dog the) = 0.11111
# P(the|dog the) = 0.11111
# P(dog|dog the) = 0.11111
# P(ran|dog the) = 0.11111
# P(on|dog the) = 0.11111
# P(the|dog the) = 0.11111
# P(floor|dog the) = 0.11111
# P(.|dog the) = 0.11111
# P(the|dog dog) = 0.11111
# P(cat|dog dog) = 0.11111
# P(jumped|dog dog) = 0.11111
# P(over|dog dog) = 0.11111
# P(the|dog dog) = 0.11111
# P(dog|dog dog) = 0.11111
# P(.|dog dog) = 0.11111
# P(the|dog dog) = 0.11111
# P(dog|dog dog) = 0.11111
# P(ran|dog dog) = 0.11111
# P(on|dog dog) = 0.11111
# P(the|dog dog) = 0.11111
# P(floor|dog dog) = 0.11111
# P(.|dog dog) = 0.11111
# P(the|dog .) = 0.20000
# P(cat|dog .) = 0.10000
# P(jumped|dog .) = 0.10000
# P(over|dog .) = 0.10000
# P(the|dog .) = 0.20000
# P(dog|dog .) = 0.10000
# P(.|dog .) = 0.10000
# P(the|dog .) = 0.20000
# P(dog|dog .) = 0.10000
# P(ran|dog .) = 0.10000
# P(on|dog .) = 0.10000
# P(the|dog .) = 0.20000
# P(floor|dog .) = 0.10000
# P(.|dog .) = 0.10000
# P(the|dog the) = 0.11111
# P(cat|dog the) = 0.11111
# P(jumped|dog the) = 0.11111
# P(over|dog the) = 0.11111
# P(the|dog the) = 0.11111
# P(dog|dog the) = 0.11111
# P(.|dog the) = 0.11111
# P(the|dog the) = 0.11111
# P(dog|dog the) = 0.11111
# P(ran|dog the) = 0.11111
# P(on|dog the) = 0.11111
# P(the|dog the) = 0.11111
# P(floor|dog the) = 0.11111
# P(.|dog the) = 0.11111
# P(the|dog dog) = 0.11111
# P(cat|dog dog) = 0.11111
# P(jumped|dog dog) = 0.11111
# P(over|dog dog) = 0.11111
# P(the|dog dog) = 0.11111
# P(dog|dog dog) = 0.11111
# P(.|dog dog) = 0.11111
# P(the|dog dog) = 0.11111
# P(dog|dog dog) = 0.11111
# P(ran|dog dog) = 0.11111
# P(on|dog dog) = 0.11111
# P(the|dog dog) = 0.11111
# P(floor|dog dog) = 0.11111
# P(.|dog dog) = 0.11111
# P(the|dog ran) = 0.10000
# P(cat|dog ran) = 0.10000
# P(jumped|dog ran) = 0.10000
# P(over|dog ran) = 0.10000
# P(the|dog ran) = 0.10000
# P(dog|dog ran) = 0.10000
# P(.|dog ran) = 0.10000
# P(the|dog ran) = 0.10000
# P(dog|dog ran) = 0.10000
# P(ran|dog ran) = 0.10000
# P(on|dog ran) = 0.20000
# P(the|dog ran) = 0.10000
# P(floor|dog ran) = 0.10000
# P(.|dog ran) = 0.10000
# P(the|dog on) = 0.11111
# P(cat|dog on) = 0.11111
# P(jumped|dog on) = 0.11111
# P(over|dog on) = 0.11111
# P(the|dog on) = 0.11111
# P(dog|dog on) = 0.11111
# P(.|dog on) = 0.11111
# P(the|dog on) = 0.11111
# P(dog|dog on) = 0.11111
# P(ran|dog on) = 0.11111
# P(on|dog on) = 0.11111
# P(the|dog on) = 0.11111
# P(floor|dog on) = 0.11111
# P(.|dog on) = 0.11111
# P(the|dog the) = 0.11111
# P(cat|dog the) = 0.11111
# P(jumped|dog the) = 0.11111
# P(over|dog the) = 0.11111
# P(the|dog the) = 0.11111
# P(dog|dog the) = 0.11111
# P(.|dog the) = 0.11111
# P(the|dog the) = 0.11111
# P(dog|dog the) = 0.11111
# P(ran|dog the) = 0.11111
# P(on|dog the) = 0.11111
# P(the|dog the) = 0.11111
# P(floor|dog the) = 0.11111
# P(.|dog the) = 0.11111
# P(the|dog floor) = 0.11111
# P(cat|dog floor) = 0.11111
# P(jumped|dog floor) = 0.11111
# P(over|dog floor) = 0.11111
# P(the|dog floor) = 0.11111
# P(dog|dog floor) = 0.11111
# P(.|dog floor) = 0.11111
# P(the|dog floor) = 0.11111
# P(dog|dog floor) = 0.11111
# P(ran|dog floor) = 0.11111
# P(on|dog floor) = 0.11111
# P(the|dog floor) = 0.11111
# P(floor|dog floor) = 0.11111
# P(.|dog floor) = 0.11111
# P(the|dog .) = 0.20000
# P(cat|dog .) = 0.10000
# P(jumped|dog .) = 0.10000
# P(over|dog .) = 0.10000
# P(the|dog .) = 0.20000
# P(dog|dog .) = 0.10000
# P(.|dog .) = 0.10000
# P(the|dog .) = 0.20000
# P(dog|dog .) = 0.10000
# P(ran|dog .) = 0.10000
# P(on|dog .) = 0.10000
# P(the|dog .) = 0.20000
# P(floor|dog .) = 0.10000
# P(.|dog .) = 0.10000
# P(the|ran the) = 0.11111
# P(cat|ran the) = 0.11111
# P(jumped|ran the) = 0.11111
# P(over|ran the) = 0.11111
# P(the|ran the) = 0.11111
# P(dog|ran the) = 0.11111
# P(.|ran the) = 0.11111
# P(the|ran the) = 0.11111
# P(dog|ran the) = 0.11111
# P(ran|ran the) = 0.11111
# P(on|ran the) = 0.11111
# P(the|ran the) = 0.11111
# P(floor|ran the) = 0.11111
# P(.|ran the) = 0.11111
# P(the|ran cat) = 0.11111
# P(cat|ran cat) = 0.11111
# P(jumped|ran cat) = 0.11111
# P(over|ran cat) = 0.11111
# P(the|ran cat) = 0.11111
# P(dog|ran cat) = 0.11111
# P(.|ran cat) = 0.11111
# P(the|ran cat) = 0.11111
# P(dog|ran cat) = 0.11111
# P(ran|ran cat) = 0.11111
# P(on|ran cat) = 0.11111
# P(the|ran cat) = 0.11111
# P(floor|ran cat) = 0.11111
# P(.|ran cat) = 0.11111
# P(the|ran jumped) = 0.11111
# P(cat|ran jumped) = 0.11111
# P(jumped|ran jumped) = 0.11111
# P(over|ran jumped) = 0.11111
# P(the|ran jumped) = 0.11111
# P(dog|ran jumped) = 0.11111
# P(.|ran jumped) = 0.11111
# P(the|ran jumped) = 0.11111
# P(dog|ran jumped) = 0.11111
# P(ran|ran jumped) = 0.11111
# P(on|ran jumped) = 0.11111
# P(the|ran jumped) = 0.11111
# P(floor|ran jumped) = 0.11111
# P(.|ran jumped) = 0.11111
# P(the|ran over) = 0.11111
# P(cat|ran over) = 0.11111
# P(jumped|ran over) = 0.11111
# P(over|ran over) = 0.11111
# P(the|ran over) = 0.11111
# P(dog|ran over) = 0.11111
# P(.|ran over) = 0.11111
# P(the|ran over) = 0.11111
# P(dog|ran over) = 0.11111
# P(ran|ran over) = 0.11111
# P(on|ran over) = 0.11111
# P(the|ran over) = 0.11111
# P(floor|ran over) = 0.11111
# P(.|ran over) = 0.11111
# P(the|ran the) = 0.11111
# P(cat|ran the) = 0.11111
# P(jumped|ran the) = 0.11111
# P(over|ran the) = 0.11111
# P(the|ran the) = 0.11111
# P(dog|ran the) = 0.11111
# P(.|ran the) = 0.11111
# P(the|ran the) = 0.11111
# P(dog|ran the) = 0.11111
# P(ran|ran the) = 0.11111
# P(on|ran the) = 0.11111
# P(the|ran the) = 0.11111
# P(floor|ran the) = 0.11111
# P(.|ran the) = 0.11111
# P(the|ran dog) = 0.11111
# P(cat|ran dog) = 0.11111
# P(jumped|ran dog) = 0.11111
# P(over|ran dog) = 0.11111
# P(the|ran dog) = 0.11111
# P(dog|ran dog) = 0.11111
# P(.|ran dog) = 0.11111
# P(the|ran dog) = 0.11111
# P(dog|ran dog) = 0.11111
# P(ran|ran dog) = 0.11111
# P(on|ran dog) = 0.11111
# P(the|ran dog) = 0.11111
# P(floor|ran dog) = 0.11111
# P(.|ran dog) = 0.11111
# P(the|ran .) = 0.11111
# P(cat|ran .) = 0.11111
# P(jumped|ran .) = 0.11111
# P(over|ran .) = 0.11111
# P(the|ran .) = 0.11111
# P(dog|ran .) = 0.11111
# P(.|ran .) = 0.11111
# P(the|ran .) = 0.11111
# P(dog|ran .) = 0.11111
# P(ran|ran .) = 0.11111
# P(on|ran .) = 0.11111
# P(the|ran .) = 0.11111
# P(floor|ran .) = 0.11111
# P(.|ran .) = 0.11111
# P(the|ran the) = 0.11111
# P(cat|ran the) = 0.11111
# P(jumped|ran the) = 0.11111
# P(over|ran the) = 0.11111
# P(the|ran the) = 0.11111
# P(dog|ran the) = 0.11111
# P(.|ran the) = 0.11111
# P(the|ran the) = 0.11111
# P(dog|ran the) = 0.11111
# P(ran|ran the) = 0.11111
# P(on|ran the) = 0.11111
# P(the|ran the) = 0.11111
# P(floor|ran the) = 0.11111
# P(.|ran the) = 0.11111
# P(the|ran dog) = 0.11111
# P(cat|ran dog) = 0.11111
# P(jumped|ran dog) = 0.11111
# P(over|ran dog) = 0.11111
# P(the|ran dog) = 0.11111
# P(dog|ran dog) = 0.11111
# P(.|ran dog) = 0.11111
# P(the|ran dog) = 0.11111
# P(dog|ran dog) = 0.11111
# P(ran|ran dog) = 0.11111
# P(on|ran dog) = 0.11111
# P(the|ran dog) = 0.11111
# P(floor|ran dog) = 0.11111
# P(.|ran dog) = 0.11111
# ...
# P(dog|on on) = 0.11111
# P(.|on on) = 0.11111
# P(the|on on) = 0.11111
# P(dog|on on) = 0.11111
# P(ran|on on) = 0.11111
# P(on|on on) = 0.11111
# P(the|on on) = 0.11111
# P(floor|on on) = 0.11111
# P(.|on on) = 0.11111
# P(the|on the) = 0.10000
# P(cat|on the) = 0.10000
# P(jumped|on the) = 0.10000
# P(over|on the) = 0.10000
# P(the|on the) = 0.10000
# P(dog|on the) = 0.10000
# P(.|on the) = 0.10000
# P(the|on the) = 0.10000
# P(dog|on the) = 0.10000
# P(ran|on the) = 0.10000
# P(on|on the) = 0.10000
# P(the|on the) = 0.10000
# P(floor|on the) = 0.20000
# P(.|on the) = 0.10000
# P(the|on floor) = 0.11111
# P(cat|on floor) = 0.11111
# P(jumped|on floor) = 0.11111
# P(over|on floor) = 0.11111
# P(the|on floor) = 0.11111
# P(dog|on floor) = 0.11111
# P(.|on floor) = 0.11111
# P(the|on floor) = 0.11111
# P(dog|on floor) = 0.11111
# P(ran|on floor) = 0.11111
# P(on|on floor) = 0.11111
# P(the|on floor) = 0.11111
# P(floor|on floor) = 0.11111
# P(.|on floor) = 0.11111
# P(the|on .) = 0.11111
# P(cat|on .) = 0.11111
# P(jumped|on .) = 0.11111
# P(over|on .) = 0.11111
# P(the|on .) = 0.11111
# P(dog|on .) = 0.11111
# P(.|on .) = 0.11111
# P(the|on .) = 0.11111
# P(dog|on .) = 0.11111
# P(ran|on .) = 0.11111
# P(on|on .) = 0.11111
# P(the|on .) = 0.11111
# P(floor|on .) = 0.11111
# P(.|on .) = 0.11111
# P(the|the the) = 0.11111
# P(cat|the the) = 0.11111
# P(jumped|the the) = 0.11111
# P(over|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(ran|the the) = 0.11111
# P(on|the the) = 0.11111
# P(the|the the) = 0.11111
# P(floor|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the cat) = 0.10000
# P(cat|the cat) = 0.10000
# P(jumped|the cat) = 0.20000
# P(over|the cat) = 0.10000
# P(the|the cat) = 0.10000
# P(dog|the cat) = 0.10000
# P(.|the cat) = 0.10000
# P(the|the cat) = 0.10000
# P(dog|the cat) = 0.10000
# P(ran|the cat) = 0.10000
# P(on|the cat) = 0.10000
# P(the|the cat) = 0.10000
# P(floor|the cat) = 0.10000
# P(.|the cat) = 0.10000
# P(the|the jumped) = 0.11111
# P(cat|the jumped) = 0.11111
# P(jumped|the jumped) = 0.11111
# P(over|the jumped) = 0.11111
# P(the|the jumped) = 0.11111
# P(dog|the jumped) = 0.11111
# P(.|the jumped) = 0.11111
# P(the|the jumped) = 0.11111
# P(dog|the jumped) = 0.11111
# P(ran|the jumped) = 0.11111
# P(on|the jumped) = 0.11111
# P(the|the jumped) = 0.11111
# P(floor|the jumped) = 0.11111
# P(.|the jumped) = 0.11111
# P(the|the over) = 0.11111
# P(cat|the over) = 0.11111
# P(jumped|the over) = 0.11111
# P(over|the over) = 0.11111
# P(the|the over) = 0.11111
# P(dog|the over) = 0.11111
# P(.|the over) = 0.11111
# P(the|the over) = 0.11111
# P(dog|the over) = 0.11111
# P(ran|the over) = 0.11111
# P(on|the over) = 0.11111
# P(the|the over) = 0.11111
# P(floor|the over) = 0.11111
# P(.|the over) = 0.11111
# P(the|the the) = 0.11111
# P(cat|the the) = 0.11111
# P(jumped|the the) = 0.11111
# P(over|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(ran|the the) = 0.11111
# P(on|the the) = 0.11111
# P(the|the the) = 0.11111
# P(floor|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the dog) = 0.09091
# P(cat|the dog) = 0.09091
# P(jumped|the dog) = 0.09091
# P(over|the dog) = 0.09091
# P(the|the dog) = 0.09091
# P(dog|the dog) = 0.09091
# P(.|the dog) = 0.18182
# P(the|the dog) = 0.09091
# P(dog|the dog) = 0.09091
# P(ran|the dog) = 0.18182
# P(on|the dog) = 0.09091
# P(the|the dog) = 0.09091
# P(floor|the dog) = 0.09091
# P(.|the dog) = 0.18182
# P(the|the .) = 0.11111
# P(cat|the .) = 0.11111
# P(jumped|the .) = 0.11111
# P(over|the .) = 0.11111
# P(the|the .) = 0.11111
# P(dog|the .) = 0.11111
# P(.|the .) = 0.11111
# P(the|the .) = 0.11111
# P(dog|the .) = 0.11111
# P(ran|the .) = 0.11111
# P(on|the .) = 0.11111
# P(the|the .) = 0.11111
# P(floor|the .) = 0.11111
# P(.|the .) = 0.11111
# P(the|the the) = 0.11111
# P(cat|the the) = 0.11111
# P(jumped|the the) = 0.11111
# P(over|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(ran|the the) = 0.11111
# P(on|the the) = 0.11111
# P(the|the the) = 0.11111
# P(floor|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the dog) = 0.09091
# P(cat|the dog) = 0.09091
# P(jumped|the dog) = 0.09091
# P(over|the dog) = 0.09091
# P(the|the dog) = 0.09091
# P(dog|the dog) = 0.09091
# P(.|the dog) = 0.18182
# P(the|the dog) = 0.09091
# P(dog|the dog) = 0.09091
# P(ran|the dog) = 0.18182
# P(on|the dog) = 0.09091
# P(the|the dog) = 0.09091
# P(floor|the dog) = 0.09091
# P(.|the dog) = 0.18182
# P(the|the ran) = 0.11111
# P(cat|the ran) = 0.11111
# P(jumped|the ran) = 0.11111
# P(over|the ran) = 0.11111
# P(the|the ran) = 0.11111
# P(dog|the ran) = 0.11111
# P(.|the ran) = 0.11111
# P(the|the ran) = 0.11111
# P(dog|the ran) = 0.11111
# P(ran|the ran) = 0.11111
# P(on|the ran) = 0.11111
# P(the|the ran) = 0.11111
# P(floor|the ran) = 0.11111
# P(.|the ran) = 0.11111
# P(the|the on) = 0.11111
# P(cat|the on) = 0.11111
# P(jumped|the on) = 0.11111
# P(over|the on) = 0.11111
# P(the|the on) = 0.11111
# P(dog|the on) = 0.11111
# P(.|the on) = 0.11111
# P(the|the on) = 0.11111
# P(dog|the on) = 0.11111
# P(ran|the on) = 0.11111
# P(on|the on) = 0.11111
# P(the|the on) = 0.11111
# P(floor|the on) = 0.11111
# P(.|the on) = 0.11111
# P(the|the the) = 0.11111
# P(cat|the the) = 0.11111
# P(jumped|the the) = 0.11111
# P(over|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the the) = 0.11111
# P(dog|the the) = 0.11111
# P(ran|the the) = 0.11111
# P(on|the the) = 0.11111
# P(the|the the) = 0.11111
# P(floor|the the) = 0.11111
# P(.|the the) = 0.11111
# P(the|the floor) = 0.10000
# P(cat|the floor) = 0.10000
# P(jumped|the floor) = 0.10000
# P(over|the floor) = 0.10000
# P(the|the floor) = 0.10000
# P(dog|the floor) = 0.10000
# P(.|the floor) = 0.20000
# P(the|the floor) = 0.10000
# P(dog|the floor) = 0.10000
# P(ran|the floor) = 0.10000
# P(on|the floor) = 0.10000
# P(the|the floor) = 0.10000
# P(floor|the floor) = 0.10000
# P(.|the floor) = 0.20000
# P(the|the .) = 0.11111
# P(cat|the .) = 0.11111
# P(jumped|the .) = 0.11111
# P(over|the .) = 0.11111
# P(the|the .) = 0.11111
# P(dog|the .) = 0.11111
# P(.|the .) = 0.11111
# P(the|the .) = 0.11111
# P(dog|the .) = 0.11111
# P(ran|the .) = 0.11111
# P(on|the .) = 0.11111
# P(the|the .) = 0.11111
# P(floor|the .) = 0.11111
# P(.|the .) = 0.11111
# P(the|floor the) = 0.11111
# P(cat|floor the) = 0.11111
# P(jumped|floor the) = 0.11111
# P(over|floor the) = 0.11111
# P(the|floor the) = 0.11111
# P(dog|floor the) = 0.11111
# P(.|floor the) = 0.11111
# P(the|floor the) = 0.11111
# P(dog|floor the) = 0.11111
# P(ran|floor the) = 0.11111
# P(on|floor the) = 0.11111
# P(the|floor the) = 0.11111
# P(floor|floor the) = 0.11111
# P(.|floor the) = 0.11111
# P(the|floor cat) = 0.11111
# P(cat|floor cat) = 0.11111
# P(jumped|floor cat) = 0.11111
# P(over|floor cat) = 0.11111
# P(the|floor cat) = 0.11111
# P(dog|floor cat) = 0.11111
# P(.|floor cat) = 0.11111
# P(the|floor cat) = 0.11111
# P(dog|floor cat) = 0.11111
# P(ran|floor cat) = 0.11111
# P(on|floor cat) = 0.11111
# P(the|floor cat) = 0.11111
# P(floor|floor cat) = 0.11111
# P(.|floor cat) = 0.11111
# P(the|floor jumped) = 0.11111
# P(cat|floor jumped) = 0.11111
# P(jumped|floor jumped) = 0.11111
# P(over|floor jumped) = 0.11111
# P(the|floor jumped) = 0.11111
# P(dog|floor jumped) = 0.11111
# P(.|floor jumped) = 0.11111
# P(the|floor jumped) = 0.11111
# P(dog|floor jumped) = 0.11111
# P(ran|floor jumped) = 0.11111
# P(on|floor jumped) = 0.11111
# P(the|floor jumped) = 0.11111
# P(floor|floor jumped) = 0.11111
# P(.|floor jumped) = 0.11111
# P(the|floor over) = 0.11111
# P(cat|floor over) = 0.11111
# P(jumped|floor over) = 0.11111
# P(over|floor over) = 0.11111
# P(the|floor over) = 0.11111
# P(dog|floor over) = 0.11111
# P(.|floor over) = 0.11111
# P(the|floor over) = 0.11111
# P(dog|floor over) = 0.11111
# P(ran|floor over) = 0.11111
# P(on|floor over) = 0.11111
# P(the|floor over) = 0.11111
# P(floor|floor over) = 0.11111
# P(.|floor over) = 0.11111
# P(the|floor the) = 0.11111
# P(cat|floor the) = 0.11111
# P(jumped|floor the) = 0.11111
# P(over|floor the) = 0.11111
# P(the|floor the) = 0.11111
# P(dog|floor the) = 0.11111
# P(.|floor the) = 0.11111
# P(the|floor the) = 0.11111
# P(dog|floor the) = 0.11111
# P(ran|floor the) = 0.11111
# P(on|floor the) = 0.11111
# P(the|floor the) = 0.11111
# P(floor|floor the) = 0.11111
# P(.|floor the) = 0.11111
# P(the|floor dog) = 0.11111
# P(cat|floor dog) = 0.11111
# P(jumped|floor dog) = 0.11111
# P(over|floor dog) = 0.11111
# P(the|floor dog) = 0.11111
# P(dog|floor dog) = 0.11111
# P(.|floor dog) = 0.11111
# P(the|floor dog) = 0.11111
# P(dog|floor dog) = 0.11111
# P(ran|floor dog) = 0.11111
# P(on|floor dog) = 0.11111
# P(the|floor dog) = 0.11111
# P(floor|floor dog) = 0.11111
# P(.|floor dog) = 0.11111
# P(the|floor .) = 0.10000
# P(cat|floor .) = 0.10000
# P(jumped|floor .) = 0.10000
# P(over|floor .) = 0.10000
# P(the|floor .) = 0.10000
# P(dog|floor .) = 0.10000
# P(.|floor .) = 0.10000
# P(the|floor .) = 0.10000
# P(dog|floor .) = 0.10000
# P(ran|floor .) = 0.10000
# P(on|floor .) = 0.10000
# P(the|floor .) = 0.10000
# P(floor|floor .) = 0.10000
# P(.|floor .) = 0.10000
# P(the|floor the) = 0.11111
# P(cat|floor the) = 0.11111
# P(jumped|floor the) = 0.11111
# P(over|floor the) = 0.11111
# P(the|floor the) = 0.11111
# P(dog|floor the) = 0.11111
# P(.|floor the) = 0.11111
# P(the|floor the) = 0.11111
# P(dog|floor the) = 0.11111
# P(ran|floor the) = 0.11111
# P(on|floor the) = 0.11111
# P(the|floor the) = 0.11111
# P(floor|floor the) = 0.11111
# P(.|floor the) = 0.11111
# P(the|floor dog) = 0.11111
# P(cat|floor dog) = 0.11111
# P(jumped|floor dog) = 0.11111
# P(over|floor dog) = 0.11111
# P(the|floor dog) = 0.11111
# P(dog|floor dog) = 0.11111
# P(.|floor dog) = 0.11111
# P(the|floor dog) = 0.11111
# P(dog|floor dog) = 0.11111
# P(ran|floor dog) = 0.11111
# P(on|floor dog) = 0.11111
# P(the|floor dog) = 0.11111
# P(floor|floor dog) = 0.11111
# P(.|floor dog) = 0.11111
# P(the|floor ran) = 0.11111
# P(cat|floor ran) = 0.11111
# P(jumped|floor ran) = 0.11111
# P(over|floor ran) = 0.11111
# P(the|floor ran) = 0.11111
# P(dog|floor ran) = 0.11111
# P(.|floor ran) = 0.11111
# P(the|floor ran) = 0.11111
# P(dog|floor ran) = 0.11111
# P(ran|floor ran) = 0.11111
# P(on|floor ran) = 0.11111
# P(the|floor ran) = 0.11111
# P(floor|floor ran) = 0.11111
# P(.|floor ran) = 0.11111
# P(the|floor on) = 0.11111
# P(cat|floor on) = 0.11111
# P(jumped|floor on) = 0.11111
# P(over|floor on) = 0.11111
# P(the|floor on) = 0.11111
# P(dog|floor on) = 0.11111
# P(.|floor on) = 0.11111
# P(the|floor on) = 0.11111
# P(dog|floor on) = 0.11111
# P(ran|floor on) = 0.11111
# P(on|floor on) = 0.11111
# P(the|floor on) = 0.11111
# P(floor|floor on) = 0.11111
# P(.|floor on) = 0.11111
# P(the|floor the) = 0.11111
# P(cat|floor the) = 0.11111
# P(jumped|floor the) = 0.11111
# P(over|floor the) = 0.11111
# P(the|floor the) = 0.11111
# P(dog|floor the) = 0.11111
# P(.|floor the) = 0.11111
# P(the|floor the) = 0.11111
# P(dog|floor the) = 0.11111
# P(ran|floor the) = 0.11111
# P(on|floor the) = 0.11111
# P(the|floor the) = 0.11111
# P(floor|floor the) = 0.11111
# P(.|floor the) = 0.11111
# P(the|floor floor) = 0.11111
# P(cat|floor floor) = 0.11111
# P(jumped|floor floor) = 0.11111
# P(over|floor floor) = 0.11111
# P(the|floor floor) = 0.11111
# P(dog|floor floor) = 0.11111
# P(.|floor floor) = 0.11111
# P(the|floor floor) = 0.11111
# P(dog|floor floor) = 0.11111
# P(ran|floor floor) = 0.11111
# P(on|floor floor) = 0.11111
# P(the|floor floor) = 0.11111
# P(floor|floor floor) = 0.11111
# P(.|floor floor) = 0.11111
# P(the|floor .) = 0.10000
# P(cat|floor .) = 0.10000
# P(jumped|floor .) = 0.10000
# P(over|floor .) = 0.10000
# P(the|floor .) = 0.10000
# P(dog|floor .) = 0.10000
# P(.|floor .) = 0.10000
# P(the|floor .) = 0.10000
# P(dog|floor .) = 0.10000
# P(ran|floor .) = 0.10000
# P(on|floor .) = 0.10000
# P(the|floor .) = 0.10000
# P(floor|floor .) = 0.10000
# P(.|floor .) = 0.10000
# P(the|. the) = 0.10000
# P(cat|. the) = 0.10000
# P(jumped|. the) = 0.10000
# P(over|. the) = 0.10000
# P(the|. the) = 0.10000
# P(dog|. the) = 0.20000
# P(.|. the) = 0.10000
# P(the|. the) = 0.10000
# P(dog|. the) = 0.20000
# P(ran|. the) = 0.10000
# P(on|. the) = 0.10000
# P(the|. the) = 0.10000
# P(floor|. the) = 0.10000
# P(.|. the) = 0.10000
# P(the|. cat) = 0.11111
# P(cat|. cat) = 0.11111
# P(jumped|. cat) = 0.11111
# P(over|. cat) = 0.11111
# P(the|. cat) = 0.11111
# P(dog|. cat) = 0.11111
# P(.|. cat) = 0.11111
# P(the|. cat) = 0.11111
# P(dog|. cat) = 0.11111
# P(ran|. cat) = 0.11111
# P(on|. cat) = 0.11111
# P(the|. cat) = 0.11111
# P(floor|. cat) = 0.11111
# P(.|. cat) = 0.11111
# P(the|. jumped) = 0.11111
# P(cat|. jumped) = 0.11111
# P(jumped|. jumped) = 0.11111
# P(over|. jumped) = 0.11111
# P(the|. jumped) = 0.11111
# P(dog|. jumped) = 0.11111
# P(.|. jumped) = 0.11111
# P(the|. jumped) = 0.11111
# P(dog|. jumped) = 0.11111
# P(ran|. jumped) = 0.11111
# P(on|. jumped) = 0.11111
# P(the|. jumped) = 0.11111
# P(floor|. jumped) = 0.11111
# P(.|. jumped) = 0.11111
# P(the|. over) = 0.11111
# P(cat|. over) = 0.11111
# P(jumped|. over) = 0.11111
# P(over|. over) = 0.11111
# P(the|. over) = 0.11111
# P(dog|. over) = 0.11111
# P(.|. over) = 0.11111
# P(the|. over) = 0.11111
# P(dog|. over) = 0.11111
# P(ran|. over) = 0.11111
# P(on|. over) = 0.11111
# P(the|. over) = 0.11111
# P(floor|. over) = 0.11111
# P(.|. over) = 0.11111
# P(the|. the) = 0.10000
# P(cat|. the) = 0.10000
# P(jumped|. the) = 0.10000
# P(over|. the) = 0.10000
# P(the|. the) = 0.10000
# P(dog|. the) = 0.20000
# P(.|. the) = 0.10000
# P(the|. the) = 0.10000
# P(dog|. the) = 0.20000
# P(ran|. the) = 0.10000
# P(on|. the) = 0.10000
# P(the|. the) = 0.10000
# P(floor|. the) = 0.10000
# P(.|. the) = 0.10000
# P(the|. dog) = 0.11111
# P(cat|. dog) = 0.11111
# P(jumped|. dog) = 0.11111
# P(over|. dog) = 0.11111
# P(the|. dog) = 0.11111
# P(dog|. dog) = 0.11111
# P(.|. dog) = 0.11111
# P(the|. dog) = 0.11111
# P(dog|. dog) = 0.11111
# P(ran|. dog) = 0.11111
# P(on|. dog) = 0.11111
# P(the|. dog) = 0.11111
# P(floor|. dog) = 0.11111
# P(.|. dog) = 0.11111
# P(the|. .) = 0.11111
# P(cat|. .) = 0.11111
# P(jumped|. .) = 0.11111
# P(over|. .) = 0.11111
# P(the|. .) = 0.11111
# P(dog|. .) = 0.11111
# P(.|. .) = 0.11111
# P(the|. .) = 0.11111
# P(dog|. .) = 0.11111
# P(ran|. .) = 0.11111
# P(on|. .) = 0.11111
# P(the|. .) = 0.11111
# P(floor|. .) = 0.11111
# P(.|. .) = 0.11111
# P(the|. the) = 0.10000
# P(cat|. the) = 0.10000
# P(jumped|. the) = 0.10000
# P(over|. the) = 0.10000
# P(the|. the) = 0.10000
# P(dog|. the) = 0.20000
# P(.|. the) = 0.10000
# P(the|. the) = 0.10000
# P(dog|. the) = 0.20000
# P(ran|. the) = 0.10000
# P(on|. the) = 0.10000
# P(the|. the) = 0.10000
# P(floor|. the) = 0.10000
# P(.|. the) = 0.10000
# P(the|. dog) = 0.11111
# P(cat|. dog) = 0.11111
# P(jumped|. dog) = 0.11111
# P(over|. dog) = 0.11111
# P(the|. dog) = 0.11111
# P(dog|. dog) = 0.11111
# P(.|. dog) = 0.11111
# P(the|. dog) = 0.11111
# P(dog|. dog) = 0.11111
# P(ran|. dog) = 0.11111
# P(on|. dog) = 0.11111
# P(the|. dog) = 0.11111
# P(floor|. dog) = 0.11111
# P(.|. dog) = 0.11111
# P(the|. ran) = 0.11111
# P(cat|. ran) = 0.11111
# P(jumped|. ran) = 0.11111
# P(over|. ran) = 0.11111
# P(the|. ran) = 0.11111
# P(dog|. ran) = 0.11111
# P(.|. ran) = 0.11111
# P(the|. ran) = 0.11111
# P(dog|. ran) = 0.11111
# P(ran|. ran) = 0.11111
# P(on|. ran) = 0.11111
# P(the|. ran) = 0.11111
# P(floor|. ran) = 0.11111
# P(.|. ran) = 0.11111
# P(the|. on) = 0.11111
# P(cat|. on) = 0.11111
# P(jumped|. on) = 0.11111
# P(over|. on) = 0.11111
# P(the|. on) = 0.11111
# P(dog|. on) = 0.11111
# P(.|. on) = 0.11111
# P(the|. on) = 0.11111
# P(dog|. on) = 0.11111
# P(ran|. on) = 0.11111
# P(on|. on) = 0.11111
# P(the|. on) = 0.11111
# P(floor|. on) = 0.11111
# P(.|. on) = 0.11111
# P(the|. the) = 0.10000
# P(cat|. the) = 0.10000
# P(jumped|. the) = 0.10000
# P(over|. the) = 0.10000
# P(the|. the) = 0.10000
# P(dog|. the) = 0.20000
# P(.|. the) = 0.10000
# P(the|. the) = 0.10000
# P(dog|. the) = 0.20000
# P(ran|. the) = 0.10000
# P(on|. the) = 0.10000
# P(the|. the) = 0.10000
# P(floor|. the) = 0.10000
# P(.|. the) = 0.10000
# P(the|. floor) = 0.11111
# P(cat|. floor) = 0.11111
# P(jumped|. floor) = 0.11111
# P(over|. floor) = 0.11111
# P(the|. floor) = 0.11111
# P(dog|. floor) = 0.11111
# P(.|. floor) = 0.11111
# P(the|. floor) = 0.11111
# P(dog|. floor) = 0.11111
# P(ran|. floor) = 0.11111
# P(on|. floor) = 0.11111
# P(the|. floor) = 0.11111
# P(floor|. floor) = 0.11111
# P(.|. floor) = 0.11111
# P(the|. .) = 0.11111
# P(cat|. .) = 0.11111
# P(jumped|. .) = 0.11111
# P(over|. .) = 0.11111
# P(the|. .) = 0.11111
# P(dog|. .) = 0.11111
# P(.|. .) = 0.11111
# P(the|. .) = 0.11111
# P(dog|. .) = 0.11111
# P(ran|. .) = 0.11111
# P(on|. .) = 0.11111
# P(the|. .) = 0.11111
# P(floor|. .) = 0.11111
# P(.|. .) = 0.11111

# %% [markdown]
# ### b) Calculate the probability of a sentence and compute the Perplexity of a sentence based on 1-gram, 2-gram, and 3-gram models.

# %%
def calculate_perplexity_1gram(tokens, train_tokens):
    n = len(tokens)
    p = 1
    
    unigram_counts, V, tokens_len = unigram_count(train_tokens)

    for token in tokens:
        p*=1/laplace_smooth_unigram_prob(token, unigram_counts, V, tokens_len)
    perplexity = p ** (1/n)
    return perplexity

# Example usage
train_corpus = "the cat jumped over the dog . the dog ran on the floor ."
train_tokens = word_tokenize(train_corpus.lower())

test_corpus = "the cat ran on the floor ."
test_tokens = word_tokenize(test_corpus.lower())

perplexity = calculate_perplexity_1gram(test_tokens, train_tokens)
print(f"Perplexity 1-gram: {perplexity:.2f}")
# Out:
# Perplexity 1-gram: 8.35

# %%
def calculate_perplexity_2gram(tokens, train_tokens):
    n = len(tokens)
    p=1
    bigram_counts, unigram_counts, V, tokens_len = bigram_count(train_tokens)

    for i in range(n - 1):
        p*=1/laplace_smooth_bigram_prob(tokens[i], tokens[i+1], bigram_counts, unigram_counts, V)

    perplexity = p ** (1/n)
    return perplexity

# Example usage
train_corpus = "the cat jumped over the dog . the dog ran on the floor ."
train_tokens = word_tokenize(train_corpus.lower())

test_corpus = "the cat ran on the floor ."
test_tokens = word_tokenize(test_corpus.lower())
perplexity = calculate_perplexity_2gram(test_tokens, train_tokens)
print(f"Perplexity 2-gram: {perplexity:.2f}")
# Out:
# Perplexity 2-gram: 4.73

# %%
def calculate_perplexity_3gram(tokens, train_tokens):
    n = len(tokens)
    p=1
    trigram_counts, bigram_counts, V = trigram_count(train_tokens)

    for i in range(n - 2):
        p*=1/laplace_smooth_trigram_prob(tokens[i], tokens[i+1], tokens[i+2], trigram_counts, bigram_counts, V)

    perplexity = p ** (1/n)
    return perplexity

# Example usage
corpus = "the cat jumped over the dog . the dog ran on the floor ."
train_tokens = word_tokenize(train_corpus.lower())

test_corpus = "the cat ran on the floor ."
test_tokens = word_tokenize(test_corpus.lower())
perplexity = calculate_perplexity_3gram(test_tokens, train_tokens)
print(f"Perplexity 3-gram: {perplexity:.2f}")
# Out:
# Perplexity 3-gram: 3.79

# %% [markdown]
# ### c) Analyze the results (Provide your own examples of spelling errors and calculate the probability of two similar sentences, where one has the correct word order and the other has an incorrect word order).

# %%
with (open('./tedtalk.txt', 'r', encoding='utf-8')) as f:
    corpus=f.read()
tokens=word_tokenize(corpus.lower())
print(f"Length of tokens: {len(tokens)}")
# Out:
# Length of tokens: 8470683

# %%
true_corpus = "She send me a good picture"
true_tokens = word_tokenize(true_corpus.lower())

false_corpus = "She me send a good picture"
false_tokens = word_tokenize(false_corpus.lower())

true_perplexity = calculate_perplexity_3gram(true_tokens, tokens)
false_perplexity = calculate_perplexity_3gram(false_tokens, tokens)

print(f"True sentence perplexity 3-gram: {true_perplexity:.2f}")
print(f"False sentence perplexity 3-gram: {false_perplexity:.2f}")
# Out:
# True sentence perplexity 3-gram: 1110.03
# False sentence perplexity 3-gram: 1533.71
